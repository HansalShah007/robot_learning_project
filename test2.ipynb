# %%
import gymnasium as gym
import minigrid
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from minigrid.wrappers import FlatObsWrapper
import time
import numpy as np
from minigrid.core.world_object import Goal
import random
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\josep\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# log
#
# 100K time steps best so far, default epsilon greedy
#
# 200K stuck, 600K stuck

# %%
# Create and wrap the environment
env_id = "MiniGrid-FourRooms-v0"

# %%
env = gym.make(env_id, render_mode = "rgb_array")
env = FlatObsWrapper(env)  # Wrap the environment to flatten the observations

# Use make_vec_env to handle vectorization
env = make_vec_env(lambda: env, n_envs=1)

# %%
# Initialize the DQN model
model = DQN("MlpPolicy", env, verbose=1,
            buffer_size=10000,
            learning_rate=1e-4,
            batch_size=32,
            exploration_initial_eps=1,
            exploration_final_eps= 0.1,
            exploration_fraction=0.8,
            )

# Train the model
model.learn(total_timesteps=100000)
model.save("dqn_minigrid_four_rooms")

# %%
# Assuming the model is saved under 'dqn_minigrid_four_rooms'
# env = gym.make("MiniGrid-FourRooms-v0", render_mode="rgb_array")
# env = FlatObsWrapper(env)
# env = make_vec_env(lambda: env, n_envs=1)

model = DQN.load("dqn_minigrid_four_rooms",env=env)

# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, env=env, n_eval_episodes=100)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")

# %%
num_episodes = 100
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        total_reward += reward
        env.render('human')  # Render the environment at each step
        #time.sleep(0.1)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env.close()  # Close the environment when done

# %%
class RewardShapingWrapper(gym.Wrapper):
    def __init__(self, env):
        super(RewardShapingWrapper, self).__init__(env)
        self.last_pos = None
        self.goal_pos = None
        self.stuck_counter = 0

    def step(self, action):
        action = self.noisy_action(action)  # Apply noise to the action for exploration
        obs, reward, done, info, extra = self.env.step(action)
        current_pos = self.env.agent_pos

        if self.goal_pos is None:
            self.goal_pos = self.get_goal_position()

        current_room = self.get_room(current_pos)
        last_room = self.get_room(self.last_pos) if self.last_pos else None

        # Check if transitioned to a new room
        if last_room and current_room and last_room != current_room:
            reward += 5.0  # Reward for moving to a new room

        # Additional vector to the nearest gap or doorway
        nearest_gap_vector = self.get_vector_to_nearest_gap(current_pos)
        obs['nearest_gap_direction'] = nearest_gap_vector  # Ensure obs is a dictionary

        # Assuming obs is a dictionary that includes 'image' and possibly other keys
        goal_direction = self.get_goal_direction(current_pos)
        # If you intend to add goal_direction to obs, you should add it as a new key-value pair
        obs['goal_direction'] = goal_direction  # Add it like this if obs is a dictionary

        # Reward shaping calculations
        if self.last_pos is not None and self.goal_pos is not None:
            distance_reward = self.calculate_reward_shaping(current_pos)
            additional_reward = self.additional_rewards(action, current_pos, self.last_pos)
            reward += distance_reward + additional_reward

        if np.array_equal(current_pos, self.goal_pos):
            reward += 100
            done = True

        if self.last_pos == current_pos:
            self.stuck_counter += 1
        else:
            self.stuck_counter = 0

        if self.stuck_counter > 3:
            obs = self.nudge_agent(current_pos) or obs
            self.stuck_counter = 0

        self.last_pos = current_pos
        return obs, reward, done, info, extra

    def reset(self, **kwargs):
        obs = self.env.reset(**kwargs)
        self.last_pos = self.env.agent_pos
        self.goal_pos = self.get_goal_position()
        self.gaps = self.find_gaps()  # Find gaps upon reset
        return obs
    
    def get_vector_to_nearest_gap(self, current_pos):
        if not self.gaps:
            return np.zeros(2)  # Default to zero vector if no gaps identified

        nearest_gap = min(self.gaps, key=lambda gap: np.linalg.norm(np.array(gap) - np.array(current_pos)))
        direction_vector = np.array(nearest_gap) - np.array(current_pos)
        norm = np.linalg.norm(direction_vector)
        return direction_vector / norm if norm != 0 else direction_vector

    
    def find_gaps(self):
        width, height = self.env.width, self.env.height
        gaps = []
        # Typically, gaps will be in the walls that divide the rooms
        # We scan horizontal and vertical mid-lines for empty spaces
        mid_vertical = width // 2
        mid_horizontal = height // 2

        # Vertical mid-line (check for empty cells)
        for y in range(height):
            if self.env.grid.get(mid_vertical, y) is None:
                gaps.append((mid_vertical, y))

        # Horizontal mid-line (check for empty cells)
        for x in range(width):
            if self.env.grid.get(x, mid_horizontal) is None:
                gaps.append((x, mid_horizontal))

        return gaps


    def get_goal_position(self):
        for x in range(self.env.width):
            for y in range(self.env.height):
                if self.env.grid.get(x, y) is not None and isinstance(self.env.grid.get(x, y), Goal):
                    return (x, y)
        return None
    
    
    def calculate_reward_shaping(self, current_pos):
        if not self.goal_pos:
            return 0
        
        epsilon = 0.01  # Small value to avoid division by zero
        prev_distance = np.linalg.norm(np.array(self.last_pos) - np.array(self.goal_pos))
        current_distance = np.linalg.norm(np.array(current_pos) - np.array(self.goal_pos))
        
        if current_distance < prev_distance:
            return 0.1 * (1 / (current_distance + epsilon))
        elif current_distance > prev_distance:
            return -0.1 * (1 / (current_distance + epsilon))
        return 0

    def additional_rewards(self, action, current_pos, prev_pos):
        prev_distance = np.linalg.norm(np.array(prev_pos) - np.array(self.goal_pos))
        current_distance = np.linalg.norm(np.array(current_pos) - np.array(self.goal_pos))
        distance_change = prev_distance - current_distance
        
        if action in [0, 1] and distance_change <= 0:
            return -0.05  # Unchanged, penalty for non-improvement
        
        reward = 0
        if action == 2 and distance_change > 0:
            reward = min(0.05 * distance_change, 1.0)  # Cap the reward to avoid excessively high values

        return reward
    

    def get_goal_direction(self, current_pos):
        if not self.goal_pos:
            return np.zeros_like(current_pos)  # Return a zero vector if goal position is not set
        # Assuming current_pos and goal_pos are numpy arrays or can be converted to them
        direction_vector = np.array(self.goal_pos) - np.array(current_pos)
        # Normalize the vector
        norm = np.linalg.norm(direction_vector)
        if norm == 0:
            return direction_vector  # Avoid division by zero if already at the goal
        return direction_vector / norm
    
    def noisy_action(self, action):
        # Add random noise to the action occasionally
        if random.random() < 0.1:  # With 10% probability, alter the action randomly
            return random.choice([0, 1, 2])  # Assuming actions are 0, 1, 2
        return action
    

    def get_possible_moves(self, current_pos):
        moves = []
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Directions: up, down, left, right

        for dx, dy in directions:
            new_pos = (current_pos[0] + dx, current_pos[1] + dy)
            if self.is_position_valid(new_pos):
                moves.append(new_pos)
        return moves

    def is_position_valid(self, pos):
        x, y = pos
        # Check if within grid bounds
        if 0 <= x < self.env.width and 0 <= y < self.env.height:
            # Check if the cell is empty (None means empty in MiniGrid)
            return self.env.grid.get(x, y) is None
        return False
    
    def nudge_agent(self, current_pos):
        possible_moves = self.get_possible_moves(current_pos)
        if possible_moves:
            new_pos = random.choice(possible_moves)
            self.env.agent_pos = new_pos  # Assuming you can set the position
            # Simulate a no-op or a neutral action to update state and get observation
            obs, _, _, _, _ = self.env.step(0)  # Consider '0' as a no-op action, if applicable
            return obs
        # If no moves are possible or other issues arise, return a default observation
        return np.zeros(self.env.observation_space.shape)  # Adjust based on the specific obs space
    
    def get_room(self, position):
        x, y = position
        if x < 10 and y < 10:
            return 1  # Top-left room
        elif x >= 10 and y < 10:
            return 2  # Top-right room
        elif x < 10 and y >= 10:
            return 3  # Bottom-left room
        elif x >= 10 and y >= 10:
            return 4  # Bottom-right room
        return 0  # Should not happen unless position is out of expected range

# %%
class ActionWrapper(gym.ActionWrapper):
    def __init__(self, env):
        super(ActionWrapper, self).__init__(env)
        # Define a new action space with only the relevant actions
        self.action_space = gym.spaces.Discrete(3)  # Only three actions: left, right, forward

    def action(self, action):
        # Map the new actions to the original actions
        action_mapping = {
            0: 0,  # left
            1: 1,  # right
            2: 2   # forward
        }
        return action_mapping[action]

# %%
from stable_baselines3.common.callbacks import BaseCallback

# class ExponentialDecayCallback(BaseCallback):
#     def __init__(self, initial_epsilon, min_epsilon, decay_rate, verbose=0):
#         super(ExponentialDecayCallback, self).__init__(verbose)
#         self.initial_epsilon = initial_epsilon
#         self.min_epsilon = min_epsilon
#         self.decay_rate = decay_rate
#         self.current_epsilon = initial_epsilon

#     def _on_step(self) -> bool:
#         # Apply exponential decay
#         self.current_epsilon = max(self.min_epsilon, self.current_epsilon * self.decay_rate)
#         self.model.exploration_rate = self.current_epsilon
#         return True

# %%
class DynamicEpsilonCallback(BaseCallback):
    def __init__(self, initial_epsilon, min_epsilon, decay_rate, check_freq, verbose=0):
        super(DynamicEpsilonCallback, self).__init__(verbose)
        self.initial_epsilon = initial_epsilon
        self.min_epsilon = min_epsilon
        self.decay_rate = decay_rate
        self.check_freq = check_freq
        self.best_mean_reward = -float('inf')

    def _on_step(self) -> bool:
        # Check if it's time to update
        if self.n_calls % self.check_freq == 0:
            # Retrieve performance (could be mean reward or other metric)
            mean_reward = np.mean([self.locals['rewards']])
            if mean_reward > self.best_mean_reward:
                self.best_mean_reward = mean_reward
                if self.verbose > 0:
                    print(f"New best mean reward: {self.best_mean_reward}, not reducing epsilon.")
            else:
                # Reduce exploration rate
                self.model.exploration_rate = max(self.min_epsilon, self.model.exploration_rate * self.decay_rate)
                if self.verbose > 0:
                    print(f"Reduced exploration rate: {self.model.exploration_rate}")

        return True

# %%
class PerformanceBasedEpsilonCallback(BaseCallback):
    def __init__(self, initial_epsilon, min_epsilon, decay_rate, increase_rate, check_freq, performance_threshold, verbose=0):
        super().__init__(verbose)
        self.initial_epsilon = initial_epsilon
        self.min_epsilon = min_epsilon
        self.decay_rate = decay_rate
        self.increase_rate = increase_rate
        self.check_freq = check_freq
        self.performance_threshold = performance_threshold
        self.best_mean_reward = -float('inf')
        self.num_episodes = 0 

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            recent_rewards = self.model.ep_info_buffer
            mean_reward = np.mean([ep_info['r'] for ep_info in recent_rewards]) if recent_rewards else 0

            # Check if performance has improved sufficiently
            if mean_reward > self.best_mean_reward * self.performance_threshold:
                self.best_mean_reward = mean_reward
                self.model.exploration_rate *= self.increase_rate
                self.model.exploration_rate = min(1.0, self.model.exploration_rate)  # Ensure it does not exceed 1
                if self.verbose > 0:
                    print(f"Increased exploration rate to: {self.model.exploration_rate}")
            elif mean_reward < self.best_mean_reward:
                # Apply decay
                self.model.exploration_rate *= self.decay_rate
                self.model.exploration_rate = max(self.min_epsilon, self.model.exploration_rate)
                if self.verbose > 0:
                    print(f"Reduced exploration rate to: {self.model.exploration_rate}")

        return True
    
    def _on_rollout_end(self) -> None:
        # Only check to adjust epsilon at the end of each rollout
        if self.num_timesteps % self.check_freq == 0:
            recent_rewards = self.model.ep_info_buffer
            mean_reward = np.mean([ep_info['r'] for ep_info in recent_rewards]) if recent_rewards else 0

            if mean_reward > self.best_mean_reward * self.performance_threshold:
                self.best_mean_reward = mean_reward
                self.model.exploration_rate *= self.increase_rate
                self.model.exploration_rate = min(1.0, self.model.exploration_rate)  # Cap the exploration rate
                if self.verbose:
                    print(f"Increased exploration rate to: {self.model.exploration_rate}")

            elif mean_reward < self.best_mean_reward:
                self.model.exploration_rate *= self.decay_rate
                self.model.exploration_rate = max(self.min_epsilon, self.model.exploration_rate)
                if self.verbose:
                    print(f"Reduced exploration rate to: {self.model.exploration_rate}")

            self.num_episodes += 1
            if self.verbose:
                print(f"Rollout ended. Total episodes: {self.num_episodes}")

# %%
# Assuming `RewardShapingWrapper` and `FlatObsWrapper` have been correctly imported and configured.
env_base = gym.make(env_id, render_mode="rgb_array")
env_reward = RewardShapingWrapper(env_base)
env_flat = FlatObsWrapper(env_reward)

obs = env_flat.reset()
action = env_flat.action_space.sample()
try:
    obs, reward, done, info, extra = env_flat.step(action)
    print("Output from FlatObsWrapper:", obs, reward, done, info)
except ValueError as e:
    print("Error during step:", e)
    output = env_flat.step(action)
    print("Actual output from FlatObsWrapper:", output)
# Out:
# Output from FlatObsWrapper: [0. 0. 0. ... 0. 0. 0.] 0 False False
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_pos to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pos` for environment variables or `env.get_wrapper_attr('agent_pos')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.width to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.width` for environment variables or `env.get_wrapper_attr('width')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.height to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.height` for environment variables or `env.get_wrapper_attr('height')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.grid to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.grid` for environment variables or `env.get_wrapper_attr('grid')` that will search the reminding wrappers.
#   logger.warn(

# %%
def create_env():
    env = gym.make(env_id, render_mode="rgb_array")
    env = ActionWrapper(env)
    env = RewardShapingWrapper(env)
    env = FlatObsWrapper(env)  
    return env

# Use the function in make_vec_env
env_vec = make_vec_env(create_env, n_envs=1)

# %%
# class CustomDQN(DQN):
#     def __init__(self, *args, decay_rate=0.995, **kwargs):
#         # Remove the decay_rate from kwargs before passing it to the superclass constructor
#         self.decay_rate = decay_rate  # Save the decay rate before calling the superclass constructor
#         super().__init__(*args, **kwargs)  # Now call the superclass constructor without the decay_rate argument
        
#         # Initialize the exploration rate with the initial exploration rate from the DQN settings
#         self.exploration_rate = self.exploration_initial_eps

#     def _on_step(self):
#         super()._on_step()  # Call the superclass method
#         # Dynamically update the exploration rate using the decay rate
#         self.exploration_rate = max(self.exploration_final_eps, self.exploration_rate * self.decay_rate)
#         #print(f"Updated exploration rate: {self.exploration_rate}")

#     def predict(self, observation, state=None, episode_start=None, deterministic=False):
#         if not deterministic and np.random.rand() < self.exploration_rate:
#             action = np.array([self.action_space.sample()])
#         else:
#             action, state = super().predict(observation, state, episode_start, deterministic=True)
#         return action, state

# %%
# call exponential callback doesn't work
#epsilon_decay_callback = ExponentialDecayCallback(initial_epsilon=1.0, min_epsilon=0.1, decay_rate=0.999)

dynamic_decay = DynamicEpsilonCallback(initial_epsilon=1.0, min_epsilon=0.1, decay_rate=0.999, check_freq=10, verbose=1)

dynamic_decay2 = PerformanceBasedEpsilonCallback(
    initial_epsilon=1.0,
    min_epsilon=0.1,
    decay_rate=0.999,
    increase_rate=1.15,
    check_freq=100,
    performance_threshold=1.1,
    verbose=0
)

model2 = DQN("MlpPolicy", env_vec, verbose=1,
            buffer_size=500000,
            learning_rate=1e-4,
            batch_size=64,
            )

# Train the model
model2.learn(total_timesteps=400000, callback=dynamic_decay2)
model2.save("dqn_minigrid_four_rooms_rs")
# Out:
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | -1.47    |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 550      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 335      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000234 |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.8     |
# |    ep_rew_mean      | -1.55    |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 476      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 598      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000209 |
# |    n_updates        | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.8     |
# |    ep_rew_mean      | -1.02    |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 446      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 934      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00027  |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.4     |
# |    ep_rew_mean      | -1.32    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 433      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1270     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000322 |
# |    n_updates        | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.3     |
# |    ep_rew_mean      | -1.53    |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 428      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1606     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000288 |
# |    n_updates        | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.6     |
# |    ep_rew_mean      | -1.67    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 425      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1934     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000466 |
# |    n_updates        | 458      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | -1.74    |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 422      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2270     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0682   |
# |    n_updates        | 542      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.4     |
# |    ep_rew_mean      | -1.82    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 421      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2606     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000316 |
# |    n_updates        | 626      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.7     |
# |    ep_rew_mean      | -1.85    |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 420      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2942     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000426 |
# |    n_updates        | 710      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.91    |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 420      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3278     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000229 |
# |    n_updates        | 794      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.1     |
# |    ep_rew_mean      | -1.72    |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 419      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3614     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000327 |
# |    n_updates        | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | -1.56    |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 417      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3950     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000212 |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | -1.55    |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 418      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4218     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000386 |
# |    n_updates        | 1029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -1.55    |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 417      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4489     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000345 |
# |    n_updates        | 1097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.4     |
# |    ep_rew_mean      | -1.59    |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 417      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00024  |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.6     |
# |    ep_rew_mean      | -1.39    |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 417      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00022  |
# |    n_updates        | 1265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.8     |
# |    ep_rew_mean      | -1.35    |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 417      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5497     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000222 |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -1.4     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 418      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5833     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000499 |
# |    n_updates        | 1433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | -1.44    |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 417      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6165     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00296  |
# |    n_updates        | 1516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.47    |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 417      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 6501     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000202 |
# |    n_updates        | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.4     |
# |    ep_rew_mean      | -1.51    |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 418      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 6837     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0665   |
# |    n_updates        | 1684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.5     |
# |    ep_rew_mean      | -1.53    |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 419      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7173     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000359 |
# |    n_updates        | 1768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.33    |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 420      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 7509     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 1852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.7     |
# |    ep_rew_mean      | -1.15    |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 420      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 7845     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000727 |
# |    n_updates        | 1936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.2     |
# |    ep_rew_mean      | -1.12    |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 420      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 8121     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0718   |
# |    n_updates        | 2005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.2     |
# |    ep_rew_mean      | -1.13    |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 421      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8457     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000348 |
# |    n_updates        | 2089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.15    |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 422      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8793     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000622 |
# |    n_updates        | 2173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | -1.22    |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 421      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 9128     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000552 |
# |    n_updates        | 2256     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | -1.2     |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 421      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 9463     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000442 |
# |    n_updates        | 2340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | -1.19    |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 422      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 9799     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0662   |
# |    n_updates        | 2424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.18    |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 421      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10135    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0708   |
# |    n_updates        | 2508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.18    |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 420      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 10471    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000238 |
# |    n_updates        | 2592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.13    |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 419      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 10739    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000547 |
# |    n_updates        | 2659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.13    |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 419      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 11075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000306 |
# |    n_updates        | 2743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.11    |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 419      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11411    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00036  |
# |    n_updates        | 2827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.14    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 419      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 11747    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000781 |
# |    n_updates        | 2911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.3     |
# |    ep_rew_mean      | -1.21    |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 419      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 12083    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000249 |
# |    n_updates        | 2995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.22    |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 419      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 12419    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000617 |
# |    n_updates        | 3079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | -1.2     |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 419      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 12678    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00046  |
# |    n_updates        | 3144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.9     |
# |    ep_rew_mean      | -0.991   |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 419      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 13014    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0714   |
# |    n_updates        | 3228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.2     |
# |    ep_rew_mean      | -1.1     |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 418      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 13285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000224 |
# |    n_updates        | 3296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -1.09    |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 419      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 13596    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0703   |
# |    n_updates        | 3373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -1.07    |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 419      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 13932    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000796 |
# |    n_updates        | 3457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -1.04    |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 418      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 14268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000313 |
# |    n_updates        | 3541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -0.904   |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 417      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 14522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000348 |
# |    n_updates        | 3605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 417      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 14857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000322 |
# |    n_updates        | 3689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -0.865   |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 417      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 15193    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00051  |
# |    n_updates        | 3773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -1.04    |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 417      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 15529    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000299 |
# |    n_updates        | 3857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -1.13    |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 417      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 15865    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00038  |
# |    n_updates        | 3941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.8     |
# |    ep_rew_mean      | -0.976   |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 416      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 16201    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00041  |
# |    n_updates        | 4025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -0.938   |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 416      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 16477    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000403 |
# |    n_updates        | 4094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | -0.856   |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 416      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 16813    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000477 |
# |    n_updates        | 4178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.1     |
# |    ep_rew_mean      | -0.644   |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 416      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 17134    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00187  |
# |    n_updates        | 4258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.6     |
# |    ep_rew_mean      | -0.624   |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 416      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 17419    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000341 |
# |    n_updates        | 4329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.5     |
# |    ep_rew_mean      | -0.55    |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 415      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 17754    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000449 |
# |    n_updates        | 4413     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | -0.492   |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 415      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 17989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000552 |
# |    n_updates        | 4472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | -0.466   |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 415      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 18325    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0713   |
# |    n_updates        | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.2     |
# |    ep_rew_mean      | -0.474   |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 415      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 18661    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000453 |
# |    n_updates        | 4640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.2     |
# |    ep_rew_mean      | -0.444   |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 414      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 18997    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000411 |
# |    n_updates        | 4724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.2     |
# |    ep_rew_mean      | -0.416   |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 413      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 19333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000353 |
# |    n_updates        | 4808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.2     |
# |    ep_rew_mean      | -0.446   |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 413      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 19669    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000405 |
# |    n_updates        | 4892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | -0.397   |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 412      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 19904    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000514 |
# |    n_updates        | 4950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | -0.382   |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 412      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 20240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 5034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -0.39    |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 412      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 20576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000424 |
# |    n_updates        | 5118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | -0.57    |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 411      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 20912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000409 |
# |    n_updates        | 5202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.8     |
# |    ep_rew_mean      | -0.557   |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 411      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 21168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000346 |
# |    n_updates        | 5266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | -0.563   |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 410      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 21422    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000326 |
# |    n_updates        | 5330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | -0.442   |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 410      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 21758    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00167  |
# |    n_updates        | 5414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | -0.426   |
# |    exploration_rate | 0.475    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 409      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 22094    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 5498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | -0.512   |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 409      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 22357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0712   |
# |    n_updates        | 5564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -0.374   |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 409      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 22623    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000724 |
# |    n_updates        | 5630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -0.357   |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 409      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 22959    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 5714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -0.287   |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 409      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 23295    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000343 |
# |    n_updates        | 5798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.295   |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 408      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 23553    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000256 |
# |    n_updates        | 5863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 408      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 23820    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000421 |
# |    n_updates        | 5929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.8     |
# |    ep_rew_mean      | -0.408   |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 407      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 24156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000445 |
# |    n_updates        | 6013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.8     |
# |    ep_rew_mean      | -0.406   |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 407      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 24492    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.07     |
# |    n_updates        | 6097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.588   |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 407      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 24828    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000221 |
# |    n_updates        | 6181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.5     |
# |    ep_rew_mean      | -0.584   |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 407      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 25164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000301 |
# |    n_updates        | 6265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.595   |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 407      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 25445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000263 |
# |    n_updates        | 6336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.3     |
# |    ep_rew_mean      | -0.593   |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 407      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 25716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000264 |
# |    n_updates        | 6403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.566   |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 406      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 26014    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000423 |
# |    n_updates        | 6478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.551   |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 406      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 26350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000315 |
# |    n_updates        | 6562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 0.474    |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 406      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 26556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00034  |
# |    n_updates        | 6613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.2     |
# |    ep_rew_mean      | 0.592    |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 406      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 26849    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000556 |
# |    n_updates        | 6687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.7     |
# |    ep_rew_mean      | 0.692    |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 405      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 27037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00272  |
# |    n_updates        | 6734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.7     |
# |    ep_rew_mean      | 0.681    |
# |    exploration_rate | 0.35     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 405      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 27370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000529 |
# |    n_updates        | 6817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.7     |
# |    ep_rew_mean      | 0.796    |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 404      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 27706    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000389 |
# |    n_updates        | 6901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 404      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 27970    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000312 |
# |    n_updates        | 6967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 403      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 28227    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000245 |
# |    n_updates        | 7031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74       |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 403      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 28563    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000358 |
# |    n_updates        | 7115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73       |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.318    |
# ...
# |    time_elapsed     | 1072     |
# |    total_timesteps  | 391574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000264 |
# |    n_updates        | 97868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.4     |
# |    ep_rew_mean      | 2.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5772     |
# |    fps              | 365      |
# |    time_elapsed     | 1073     |
# |    total_timesteps  | 391892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 97947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.4     |
# |    ep_rew_mean      | 2.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5776     |
# |    fps              | 365      |
# |    time_elapsed     | 1074     |
# |    total_timesteps  | 392228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 98031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.4     |
# |    ep_rew_mean      | 2.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5780     |
# |    fps              | 364      |
# |    time_elapsed     | 1075     |
# |    total_timesteps  | 392506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00191  |
# |    n_updates        | 98101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67       |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5784     |
# |    fps              | 365      |
# |    time_elapsed     | 1076     |
# |    total_timesteps  | 392842   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00023  |
# |    n_updates        | 98185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5788     |
# |    fps              | 365      |
# |    time_elapsed     | 1076     |
# |    total_timesteps  | 393104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000927 |
# |    n_updates        | 98250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.8     |
# |    ep_rew_mean      | 2.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5792     |
# |    fps              | 364      |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 393153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000806 |
# |    n_updates        | 98263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.2     |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5796     |
# |    fps              | 364      |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 393471   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000173 |
# |    n_updates        | 98342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.9     |
# |    ep_rew_mean      | 2.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5800     |
# |    fps              | 365      |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 393807   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 98426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 2.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5804     |
# |    fps              | 364      |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 394079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0715   |
# |    n_updates        | 98494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.2     |
# |    ep_rew_mean      | 2.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5808     |
# |    fps              | 364      |
# |    time_elapsed     | 1080     |
# |    total_timesteps  | 394337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000784 |
# |    n_updates        | 98559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.7     |
# |    ep_rew_mean      | 2.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5812     |
# |    fps              | 364      |
# |    time_elapsed     | 1081     |
# |    total_timesteps  | 394666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 98641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 2.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5816     |
# |    fps              | 365      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 394949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000864 |
# |    n_updates        | 98712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.3     |
# |    ep_rew_mean      | 2.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5820     |
# |    fps              | 365      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 395217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000861 |
# |    n_updates        | 98779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.1     |
# |    ep_rew_mean      | 2.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5824     |
# |    fps              | 365      |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 395553   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00236  |
# |    n_updates        | 98863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5828     |
# |    fps              | 365      |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 395796   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000316 |
# |    n_updates        | 98923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.5     |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5832     |
# |    fps              | 365      |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 395982   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000558 |
# |    n_updates        | 98970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.7     |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5836     |
# |    fps              | 365      |
# |    time_elapsed     | 1085     |
# |    total_timesteps  | 396232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000354 |
# |    n_updates        | 99032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.1     |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5840     |
# |    fps              | 365      |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 396567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 99116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.9     |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5844     |
# |    fps              | 365      |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 396780   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 99169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5848     |
# |    fps              | 365      |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 397051   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0696   |
# |    n_updates        | 99237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5852     |
# |    fps              | 365      |
# |    time_elapsed     | 1088     |
# |    total_timesteps  | 397329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000423 |
# |    n_updates        | 99307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.7     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5856     |
# |    fps              | 364      |
# |    time_elapsed     | 1089     |
# |    total_timesteps  | 397665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00474  |
# |    n_updates        | 99391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 0.286    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5860     |
# |    fps              | 364      |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 398001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 99475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | 0.287    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5864     |
# |    fps              | 364      |
# |    time_elapsed     | 1091     |
# |    total_timesteps  | 398337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000729 |
# |    n_updates        | 99559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.7     |
# |    ep_rew_mean      | 0.311    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5868     |
# |    fps              | 364      |
# |    time_elapsed     | 1092     |
# |    total_timesteps  | 398641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000899 |
# |    n_updates        | 99635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.2     |
# |    ep_rew_mean      | 0.317    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5872     |
# |    fps              | 364      |
# |    time_elapsed     | 1092     |
# |    total_timesteps  | 398916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00057  |
# |    n_updates        | 99703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.5     |
# |    ep_rew_mean      | 0.327    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5876     |
# |    fps              | 364      |
# |    time_elapsed     | 1093     |
# |    total_timesteps  | 399182   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0014   |
# |    n_updates        | 99770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.5     |
# |    ep_rew_mean      | 0.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5880     |
# |    fps              | 364      |
# |    time_elapsed     | 1094     |
# |    total_timesteps  | 399451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00141  |
# |    n_updates        | 99837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.5     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5884     |
# |    fps              | 364      |
# |    time_elapsed     | 1095     |
# |    total_timesteps  | 399787   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000761 |
# |    n_updates        | 99921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.5     |
# |    ep_rew_mean      | 0.427    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5888     |
# |    fps              | 364      |
# |    time_elapsed     | 1095     |
# |    total_timesteps  | 399856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000745 |
# |    n_updates        | 99938    |
# ----------------------------------

# %%
model2 = DQN.load("dqn_minigrid_four_rooms_rs",env=env_vec)


# Evaluate the model
mean_reward2, std_reward2 = evaluate_policy(model2, env=env_vec, n_eval_episodes=100)
print(f"Mean Reward with reward shaping: {mean_reward2} +/- {std_reward2}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_pos to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pos` for environment variables or `env.get_wrapper_attr('agent_pos')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.width to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.width` for environment variables or `env.get_wrapper_attr('width')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.height to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.height` for environment variables or `env.get_wrapper_attr('height')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.grid to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.grid` for environment variables or `env.get_wrapper_attr('grid')` that will search the reminding wrappers.
#   logger.warn(
# Mean Reward with reward shaping: 0.7903041999999999 +/- 2.778390124658389

# %%
num_episodes = 200
total_rewards2 = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model2.predict(obs, deterministic=True)
        print("Action chosen:", action)
        obs, reward, done, info= env_vec.step(action)  # Adjust to capture both terminated and truncated
        #done = truncated  # Consider episode done if either flag is True
        print("Reward received:", reward)
        total_reward += reward
        env_vec.render('human')  # Render the environment at each step
        time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards2.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward2 = sum(total_rewards2) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward2}")

env_vec.close()  # Close the environment when done
# Out:
# Action chosen: [2]
# Reward received: [100.]
# Episode 1: Total Reward = [100.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.02231079]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01996008]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06138277]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01996008]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01488493]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03496886]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01488493]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.0609831]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06150768]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04082447]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04082447]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01488493]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.0609831]
# Episode 2: Total Reward = [-0.11389329]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [5.0508227]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [4.9907637]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00876289]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00829766]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0078026]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04653035]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0078026]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00742742]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.00785057]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05742742]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04413567]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00742742]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04413567]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00742742]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00706607]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00672221]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 3: Total Reward = [9.958075]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06155464]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06155464]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.03152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04133647]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.09975124]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.03322259]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.03152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04133647]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.03152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.02419488]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01957323]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.07299057]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 4: Total Reward = [-0.00603508]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06582818]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01578643]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06550464]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01578643]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01641292]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02077706]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01641292]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01412216]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01238811]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01103097]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.06083477]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06077875]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01169043]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02700172]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01083477]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01052983]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 5: Total Reward = [-0.07311354]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01371721]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01311342]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06026339]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01311342]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [0.01488493]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.0609831]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01488493]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01311342]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01238811]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03543766]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01238811]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05640606]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05599194]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01764647]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01559302]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01412216]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Episode 6: Total Reward = [-0.07082028]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00759708]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0074897]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05669535]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0074897]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00697943]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00686331]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01909936]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05629755]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01703296]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01339085]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05813817]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00711963]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05752697]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05813817]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0082132]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 7: Total Reward = [0.12690355]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01040612]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0076864]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.00832639]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0076864]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.00960664]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05813817]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01040612]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00829766]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05813817]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05759708]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05758427]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00759708]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 8: Total Reward = [-0.05691382]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02664607]
# Action chosen: [0]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.928]
# Episode 9: Total Reward = [0.854646]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02077706]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01641292]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02077706]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01641292]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01412216]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01371721]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01412216]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01781873]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01412216]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06582818]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.06578643]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [1]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [-0.01371721]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02457427]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [1]
# Reward received: [-0.06371722]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06356416]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02850256]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06876038]
# Episode 10: Total Reward = [-0.19328369]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02850679]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05411692]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0076864]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05717443]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00697943]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05656102]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05266568]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05251867]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [1]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [0]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [-0.05719298]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.487]
# Episode 11: Total Reward = [0.2892138]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.11130691]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.09452225]
# Action chosen: [0]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.892]
# Episode 12: Total Reward = [0.8587847]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04955583]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00619789]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00600481]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00580901]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00561341]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03580117]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03407149]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00571335]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.03052168]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02839031]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05140816]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02760749]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02499608]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00656101]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05266568]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02664607]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [0]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [-0.05697943]
# Action chosen: [2]
# Reward received: [0.]
# Episode 13: Total Reward = [-0.03121495]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [0]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [-0.09975124]
# Action chosen: [2]
# Reward received: [0.946]
# Episode 14: Total Reward = [0.79624873]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01957323]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.07299057]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.06957322]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01641292]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01578643]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01488493]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01311342]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01238811]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [-0.01161127]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05239109]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01161127]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05239109]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01161127]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.06083477]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04247222]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05239109]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01177124]
# Episode 15: Total Reward = [-0.24653596]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01103097]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01386804]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00999001]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06109878]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01103097]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01386804]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00999001]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00994048]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00904539]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05971475]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06075549]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00994048]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01248379]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [-0.00994048]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06075549]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01083477]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Episode 16: Total Reward = [-0.00919918]
# Action chosen: [1]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00908265]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05999001]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01109878]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01103097]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00994048]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01103097]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.01386804]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00999001]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00994048]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01248379]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00908265]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00832639]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0076864]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00766377]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00711963]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00706607]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 17: Total Reward = [-0.2884579]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.11130691]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.11972058]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.07021419]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.11972058]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.09975124]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# ...
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01559302]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04572912]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [1]
# Reward received: [-0.05]
# Action chosen: [1]
# Reward received: [0.01996008]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0171205]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.01559302]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0138483]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01559302]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0138483]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04002986]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03496886]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06550464]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03388049]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.02419488]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.02231079]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.07098753]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.02231079]
# Episode 189: Total Reward = [-0.08689676]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03581869]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00666223]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00639775]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03768719]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04639751]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00672221]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00642411]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04123623]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00642411]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00613918]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.03931381]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05613918]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00588909]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04072629]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04254768]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00613918]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Episode 190: Total Reward = [-0.07320964]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00893628]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01579433]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.0113507]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00832639]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00829766]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05885706]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00893628]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0582132]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00759708]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00706607]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01244297]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00706607]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01244297]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00664748]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00660382]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.01161996]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Episode 191: Total Reward = [-0.30518237]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.05368677]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04133647]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.08152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [1]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04133647]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.09975124]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.03152309]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.09083273]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.06155464]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.11130691]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.09452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.11130691]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.04452225]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.08523078]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.0276583]
# Action chosen: [2]
# Reward received: [-0.05]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Episode 192: Total Reward = [-0.09291211]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.00666223]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00632056]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.04723164]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [-0.00632056]
# Action chosen: [2]
# Reward received: [0.]
# Action chosen: [2]
# Reward received: [0.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 16
#      14     total_reward += reward
#      15     env_vec.render('human')  # Render the environment at each step
# ---> 16     time.sleep(0.05)  # Adjust this to control the speed of the rendering
#      17 total_rewards2.append(total_reward)  # Store the total reward for this episode
#      18 print(f"Episode {episode + 1}: Total Reward = {total_reward}")
#
# KeyboardInterrupt:
