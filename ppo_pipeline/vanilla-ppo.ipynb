# %% [markdown]
# # Vanilla PPO
#
# Run on 3 environments
#
# Empty Room
#
# Empty Room Random
#
# Four Rooms

# %%
import gymnasium as gym
import minigrid
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from minigrid.wrappers import FlatObsWrapper
import time
import numpy as np
from minigrid.core.world_object import Goal
import random
from stable_baselines3.common.callbacks import BaseCallback
from gymnasium.envs.registration import register
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # First Empty

# %%
# Create and wrap the environment
env_id = "MiniGrid-Empty-16x16-v0"

# %%
def create_env():
    env = gym.make(env_id, render_mode="rgb_array")#,max_episode_steps=200)
    env = FlatObsWrapper(env)  
    return env

# Use the function in make_vec_env
env_vec = make_vec_env(create_env, n_envs=1)
env_vec2 = make_vec_env(create_env, n_envs=4)

# %%
model = PPO("MlpPolicy", env_vec2, verbose=1,
            tensorboard_log="log/ppo_vanilla_empty_no_step_cap/"
            )

# Train the model
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to log/ppo_vanilla_empty_no_step_cap/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 0.0334   |
# | time/              |          |
# |    fps             | 5271     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 0.0167      |
# | time/                   |             |
# |    fps                  | 2836        |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019228809 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -1.54       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0063      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.0088      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0.0111      |
# | time/                   |             |
# |    fps                  | 2441        |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015733913 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -0.304      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.000797    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0.00834     |
# | time/                   |             |
# |    fps                  | 2293        |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016680297 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | -0.609      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.009      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 0.00667    |
# | time/                   |            |
# |    fps                  | 2209       |
# |    iterations           | 5          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01540646 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.87      |
# |    explained_variance   | -0.844     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0132     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 3.72e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0.00556     |
# | time/                   |             |
# |    fps                  | 2158        |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013710384 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | -0.331      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0029     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 2.29e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 938        |
# |    ep_rew_mean          | 0.096      |
# | time/                   |            |
# |    fps                  | 2130       |
# |    iterations           | 7          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01831771 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | -0.434     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0262    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.008     |
# |    value_loss           | 1.82e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 818         |
# |    ep_rew_mean          | 0.22        |
# | time/                   |             |
# |    fps                  | 2104        |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011710808 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.0871     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00997     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 0.503       |
# | time/                   |             |
# |    fps                  | 2071        |
# |    iterations           | 9           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020000491 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0384     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00974    |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 0.867       |
# | time/                   |             |
# |    fps                  | 2063        |
# |    iterations           | 10          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018031664 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00657    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.00903     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.2        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 2057        |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012700574 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.018       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.1        |
# |    ep_rew_mean          | 0.945       |
# | time/                   |             |
# |    fps                  | 2050        |
# |    iterations           | 12          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013910865 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 0.958       |
# | time/                   |             |
# |    fps                  | 2047        |
# |    iterations           | 13          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.015661102 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00357    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.022       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.7       |
# |    ep_rew_mean          | 0.965      |
# | time/                   |            |
# |    fps                  | 2033       |
# |    iterations           | 14         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.01026142 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0366    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 0.0162     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 2028        |
# |    iterations           | 15          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.008402962 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00468    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.6         |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 2021         |
# |    iterations           | 16           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0068139452 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00819     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00758     |
# |    value_loss           | 0.00646      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.6        |
# |    ep_rew_mean          | 0.971       |
# | time/                   |             |
# |    fps                  | 2017        |
# |    iterations           | 17          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.006004098 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.9         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 2018         |
# |    iterations           | 18           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0036446447 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000235    |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 0.00358      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.6       |
# |    ep_rew_mean          | 0.973      |
# | time/                   |            |
# |    fps                  | 2015       |
# |    iterations           | 19         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.00316953 |
# |    clip_fraction        | 0.0496     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.437     |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0123    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00372   |
# |    value_loss           | 0.00312    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | 0.974        |
# | time/                   |              |
# |    fps                  | 2015         |
# |    iterations           | 20           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0036736112 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00328     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 0.00278      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 2015        |
# |    iterations           | 21          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002960469 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00389    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.2         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 2015         |
# |    iterations           | 22           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0034025523 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0.606        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00624     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 2014         |
# |    iterations           | 23           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0014179209 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00357      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.00238      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.3          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 2008          |
# |    iterations           | 24            |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00096196955 |
# |    clip_fraction        | 0.0133        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.18         |
# |    explained_variance   | 0.601         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.43e-05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00085      |
# |    value_loss           | 0.00226       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.9         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 2007         |
# |    iterations           | 25           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0022119088 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.173       |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00385     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 0.0022       |
# ------------------------------------------

# %%
model.save("models/ppo_vanilla_empty_no_step_cap")

# %%
model = PPO.load("models/ppo_vanilla_empty_no_step_cap",env=env_vec)

mean_reward, std_reward = evaluate_policy(model, env=env_vec, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# Mean Reward: 0.9762699999999999 +/- 1.1102230246251565e-16

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env_vec.step(action)
        #print(done)
        total_reward += reward
        env_vec.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.97626954]
# Episode 2: Total Reward = [0.97626954]
# Episode 3: Total Reward = [0.97626954]
# Episode 4: Total Reward = [0.9753906]
# Episode 5: Total Reward = [0.9753906]
# Episode 6: Total Reward = [0.97626954]
# Episode 7: Total Reward = [0.97626954]
# Episode 8: Total Reward = [0.97626954]
# Episode 9: Total Reward = [0.97451174]
# Episode 10: Total Reward = [0.97626954]
# Episode 11: Total Reward = [0.97626954]
# Episode 12: Total Reward = [0.97626954]
# Episode 13: Total Reward = [0.97626954]
# Episode 14: Total Reward = [0.97626954]
# Episode 15: Total Reward = [0.9753906]
# Episode 16: Total Reward = [0.97451174]
# Episode 17: Total Reward = [0.97626954]
# Episode 18: Total Reward = [0.97626954]
# Episode 19: Total Reward = [0.97626954]
# Episode 20: Total Reward = [0.97626954]
# Episode 21: Total Reward = [0.97626954]
# Episode 22: Total Reward = [0.9753906]
# Episode 23: Total Reward = [0.97626954]
# Episode 24: Total Reward = [0.9727539]
# Episode 25: Total Reward = [0.97626954]
# Episode 26: Total Reward = [0.97626954]
# Episode 27: Total Reward = [0.97626954]
# Episode 28: Total Reward = [0.97626954]
# Episode 29: Total Reward = [0.97626954]
# Episode 30: Total Reward = [0.9753906]
# Episode 31: Total Reward = [0.97626954]
# Episode 32: Total Reward = [0.97626954]
# Episode 33: Total Reward = [0.97626954]
# Episode 34: Total Reward = [0.97626954]
# Episode 35: Total Reward = [0.9736328]
# Episode 36: Total Reward = [0.9753906]
# Episode 37: Total Reward = [0.9753906]
# Episode 38: Total Reward = [0.9753906]
# Episode 39: Total Reward = [0.97451174]
# Episode 40: Total Reward = [0.97626954]
# Episode 41: Total Reward = [0.97626954]
# Episode 42: Total Reward = [0.97626954]
# Episode 43: Total Reward = [0.97626954]
# Episode 44: Total Reward = [0.97626954]
# Episode 45: Total Reward = [0.9753906]
# Episode 46: Total Reward = [0.97451174]
# Episode 47: Total Reward = [0.9753906]
# Episode 48: Total Reward = [0.9753906]
# Episode 49: Total Reward = [0.97626954]
# Episode 50: Total Reward = [0.97626954]
# Average Reward over 50 episodes: [0.9758123]

# %% [markdown]
# # Empty random room

# %%
register(
    id='custom_empty-v0',
    entry_point='emptyrandom:RandomGoalEmptyEnv',
    kwargs={}
)

# %%
#gym.pprint_registry()  # to see all registered environments

if 'custom_empty-v0' in gym.envs.registry:
    print("Environment 'custom_empty-v0' is registered.")
else:
    print("Environment 'custom_empty-v0' is NOT registered.")
# Out:
# Environment 'custom_empty-v0' is registered.

# %%
env_id2 = 'custom_empty-v0'
def create_env():
    env = gym.make(env_id2, render_mode="rgb_array",size=16)
    env = FlatObsWrapper(env)  
    return env

env_vec_ran = make_vec_env(create_env, n_envs=1)
env_vec_ran2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the PPO model2
model2 = PPO("MlpPolicy", env_vec_ran2, verbose=1,
            tensorboard_log="log/ppo_vanilla_empty_random_no_step_cap"
            )

# Train the model
model2.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to log/ppo_vanilla_empty_random_no_step_cap/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 564      |
# |    ep_rew_mean     | 0.465    |
# | time/              |          |
# |    fps             | 5227     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 0.272       |
# | time/                   |             |
# |    fps                  | 2683        |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010537488 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -2.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0413     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | 0.248       |
# | time/                   |             |
# |    fps                  | 2312        |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016531045 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0573     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 776         |
# |    ep_rew_mean          | 0.263       |
# | time/                   |             |
# |    fps                  | 2171        |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012896933 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 759         |
# |    ep_rew_mean          | 0.279       |
# | time/                   |             |
# |    fps                  | 2088        |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010889247 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 0.00199     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 2040        |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011061053 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000129    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 674         |
# |    ep_rew_mean          | 0.366       |
# | time/                   |             |
# |    fps                  | 2019        |
# |    iterations           | 7           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010288819 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00436     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | 0.446       |
# | time/                   |             |
# |    fps                  | 2008        |
# |    iterations           | 8           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012024637 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0493     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00593     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 1989        |
# |    iterations           | 9           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010639035 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00921     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | 0.748       |
# | time/                   |             |
# |    fps                  | 1975        |
# |    iterations           | 10          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012792574 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00481    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | 0.835       |
# | time/                   |             |
# |    fps                  | 1964        |
# |    iterations           | 11          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012425987 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0438     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00978     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 0.879        |
# | time/                   |              |
# |    fps                  | 1957         |
# |    iterations           | 12           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0124202315 |
# |    clip_fraction        | 0.175        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00654      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.0186       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 0.908       |
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 13          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013366245 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.0197      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.6        |
# |    ep_rew_mean          | 0.934       |
# | time/                   |             |
# |    fps                  | 1928        |
# |    iterations           | 14          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.011791135 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.2        |
# |    ep_rew_mean          | 0.929       |
# | time/                   |             |
# |    fps                  | 1922        |
# |    iterations           | 15          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013407759 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00207     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00981    |
# |    value_loss           | 0.022       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.1        |
# |    ep_rew_mean          | 0.942       |
# | time/                   |             |
# |    fps                  | 1915        |
# |    iterations           | 16          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.013007201 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 0.019       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72          |
# |    ep_rew_mean          | 0.936       |
# | time/                   |             |
# |    fps                  | 1906        |
# |    iterations           | 17          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.012824018 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0309      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 0.0189      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.6        |
# |    ep_rew_mean          | 0.942       |
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 18          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012038883 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00206     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 0.0145      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.2        |
# |    ep_rew_mean          | 0.953       |
# | time/                   |             |
# |    fps                  | 1888        |
# |    iterations           | 19          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.012258709 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 0.0132      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65          |
# |    ep_rew_mean          | 0.942       |
# | time/                   |             |
# |    fps                  | 1880        |
# |    iterations           | 20          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011043265 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.8        |
# |    ep_rew_mean          | 0.957       |
# | time/                   |             |
# |    fps                  | 1879        |
# |    iterations           | 21          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.009318035 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0118      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.2       |
# |    ep_rew_mean          | 0.962      |
# | time/                   |            |
# |    fps                  | 1876       |
# |    iterations           | 22         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01032705 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.592      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0054    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00627   |
# |    value_loss           | 0.0115     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 0.958       |
# | time/                   |             |
# |    fps                  | 1875        |
# |    iterations           | 23          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010875153 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00811    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 0.00909     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55.3         |
# |    ep_rew_mean          | 0.95         |
# | time/                   |              |
# |    fps                  | 1869         |
# |    iterations           | 24           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0072497167 |
# |    clip_fraction        | 0.0971       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00336     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 0.00913      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.1         |
# |    ep_rew_mean          | 0.967        |
# | time/                   |              |
# |    fps                  | 1870         |
# |    iterations           | 25           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0070168613 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00742      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 0.00899      |
# ------------------------------------------

# %%
model2.save("models/ppo_vanilla_empty_random_no_step_cap")

# %%
model2 = PPO.load("models/ppo_vanilla_empty_random_no_step_cap",env=env_vec_ran)

mean_reward, std_reward = evaluate_policy(model2, env=env_vec_ran, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# Mean Reward: 0.39618552 +/- 0.4852366355860711

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_ran.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model2.predict(obs)
        obs, reward, done, info = env_vec_ran.step(action)
        #print(done)
        total_reward += reward
        env_vec_ran.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_ran.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.9850586]
# Episode 2: Total Reward = [0.9586914]
# Episode 3: Total Reward = [0.9639648]
# Episode 4: Total Reward = [0.9736328]
# Episode 5: Total Reward = [0.9833008]
# Episode 6: Total Reward = [0.9542969]
# Episode 7: Total Reward = [0.9490234]
# Episode 8: Total Reward = [0.99560547]
# Episode 9: Total Reward = [0.9824219]
# Episode 10: Total Reward = [0.971875]
# Episode 11: Total Reward = [0.9595703]
# Episode 12: Total Reward = [0.9885742]
# Episode 13: Total Reward = [0.9868164]
# Episode 14: Total Reward = [0.99472654]
# Episode 15: Total Reward = [0.96132815]
# Episode 16: Total Reward = [0.9657227]
# Episode 17: Total Reward = [0.9446289]
# Episode 18: Total Reward = [0.99208987]
# Episode 19: Total Reward = [0.9868164]
# Episode 20: Total Reward = [0.9727539]
# Episode 21: Total Reward = [0.99121094]
# Episode 22: Total Reward = [0.96132815]
# Episode 23: Total Reward = [0.97451174]
# Episode 24: Total Reward = [0.97978514]
# Episode 25: Total Reward = [0.86025393]
# Episode 26: Total Reward = [0.98769534]
# Episode 27: Total Reward = [0.9833008]
# Episode 28: Total Reward = [0.9525391]
# Episode 29: Total Reward = [0.990332]
# Episode 30: Total Reward = [0.9560547]
# Episode 31: Total Reward = [0.9806641]
# Episode 32: Total Reward = [0.9428711]
# Episode 33: Total Reward = [0.96484375]
# Episode 34: Total Reward = [0.9165039]
# Episode 35: Total Reward = [0.98154294]
# Episode 36: Total Reward = [0.9560547]
# Episode 37: Total Reward = [0.9578125]
# Episode 38: Total Reward = [0.990332]
# Episode 39: Total Reward = [0.97978514]
# Episode 40: Total Reward = [0.94814456]
# Episode 41: Total Reward = [0.990332]
# Episode 42: Total Reward = [0.93759763]
# Episode 43: Total Reward = [0.98945314]
# Episode 44: Total Reward = [0.9569336]
# Episode 45: Total Reward = [0.99384767]
# Episode 46: Total Reward = [0.94990236]
# Episode 47: Total Reward = [0.99560547]
# Episode 48: Total Reward = [0.9578125]
# Episode 49: Total Reward = [0.99296874]
# Episode 50: Total Reward = [0.98945314]
# Average Reward over 50 episodes: [0.96960753]

# %% [markdown]
# # Now Four rooms

# %%
env_id3 = "MiniGrid-FourRooms-v0"
def create_env():
    env = gym.make(env_id3, render_mode="rgb_array")
    env = FlatObsWrapper(env)  
    return env

env_vec_four = make_vec_env(create_env, n_envs=1)
env_vec_four2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model3 = PPO("MlpPolicy", env_vec_four2, verbose=1,
            tensorboard_log="log/ppo_vanilla_four_no_step_cap"
            )

# Train the model
model3.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# Logging to log/ppo_vanilla_four_no_step_cap/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 0.0099   |
# | time/              |          |
# |    fps             | 4562     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 0.00406     |
# | time/                   |             |
# |    fps                  | 2576        |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017583378 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -1.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0226     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.032       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | 0.00928     |
# | time/                   |             |
# |    fps                  | 2254        |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014148565 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.00123     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 0.00453     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.6       |
# |    ep_rew_mean          | 0.0246     |
# | time/                   |            |
# |    fps                  | 2138       |
# |    iterations           | 4          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01990806 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.88      |
# |    explained_variance   | 0.112      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0113    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 0.00142    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | 0.00937     |
# | time/                   |             |
# |    fps                  | 2074        |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015622858 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | -0.00636    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0397     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 0.000567    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.2        |
# |    ep_rew_mean          | 0.00775     |
# | time/                   |             |
# |    fps                  | 2038        |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017710464 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -1.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.00014     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.5        |
# |    ep_rew_mean          | 0.0363      |
# | time/                   |             |
# |    fps                  | 2013        |
# |    iterations           | 7           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010612763 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.0712     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.045      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.000596    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.9        |
# |    ep_rew_mean          | 0.022       |
# | time/                   |             |
# |    fps                  | 1992        |
# |    iterations           | 8           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011298661 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.000701    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1976        |
# |    iterations           | 9           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013085211 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.000325    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | 0.0201      |
# | time/                   |             |
# |    fps                  | 1943        |
# |    iterations           | 10          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012007581 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -2.71       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0312     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | 0.0206      |
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 11          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015233941 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0389     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.000392    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98          |
# |    ep_rew_mean          | 0.0219      |
# | time/                   |             |
# |    fps                  | 1907        |
# |    iterations           | 12          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014194218 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00053     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.2        |
# |    ep_rew_mean          | 0.0301      |
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013695536 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.0528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.000638    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.1         |
# |    ep_rew_mean          | 0.01         |
# | time/                   |              |
# |    fps                  | 1892         |
# |    iterations           | 14           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0151488185 |
# |    clip_fraction        | 0.184        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0418      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0171      |
# |    value_loss           | 0.000813     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.9         |
# |    ep_rew_mean          | 0.0328       |
# | time/                   |              |
# |    fps                  | 1887         |
# |    iterations           | 15           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0147295175 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0574      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 0.000315     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.3        |
# |    ep_rew_mean          | 0.0169      |
# | time/                   |             |
# |    fps                  | 1879        |
# |    iterations           | 16          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.012204391 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000668    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.3       |
# |    ep_rew_mean          | 0.00712    |
# | time/                   |            |
# |    fps                  | 1873       |
# |    iterations           | 17         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.02050794 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.461      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0128    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 0.000278   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.9        |
# |    ep_rew_mean          | 0.0221      |
# | time/                   |             |
# |    fps                  | 1868        |
# |    iterations           | 18          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.013768956 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0506     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.00016     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.1        |
# |    ep_rew_mean          | 0.0419      |
# | time/                   |             |
# |    fps                  | 1865        |
# |    iterations           | 19          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.012750171 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0326     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.000607    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.3        |
# |    ep_rew_mean          | 0.0283      |
# | time/                   |             |
# |    fps                  | 1857        |
# |    iterations           | 20          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.012376208 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.04       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.000755    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.5        |
# |    ep_rew_mean          | 0.0269      |
# | time/                   |             |
# |    fps                  | 1852        |
# |    iterations           | 21          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.012895698 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0541     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.000647    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97           |
# |    ep_rew_mean          | 0.0315       |
# | time/                   |              |
# |    fps                  | 1850         |
# |    iterations           | 22           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0123886075 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00261     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.000334     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.9        |
# |    ep_rew_mean          | 0.0329      |
# | time/                   |             |
# |    fps                  | 1852        |
# |    iterations           | 23          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.014970446 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0368     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.00021     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.3        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 1852        |
# |    iterations           | 24          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.013443865 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00125     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.000724    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.7        |
# |    ep_rew_mean          | 0.0566      |
# | time/                   |             |
# |    fps                  | 1850        |
# |    iterations           | 25          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.015004648 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000215   |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.7        |
# |    ep_rew_mean          | 0.026       |
# | time/                   |             |
# |    fps                  | 1845        |
# |    iterations           | 26          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.011966296 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0516     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.4        |
# |    ep_rew_mean          | 0.0694      |
# | time/                   |             |
# |    fps                  | 1844        |
# |    iterations           | 27          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.015238065 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0333     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.000432    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.4        |
# |    ep_rew_mean          | 0.0588      |
# | time/                   |             |
# |    fps                  | 1839        |
# |    iterations           | 28          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014572069 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.6        |
# |    ep_rew_mean          | 0.0457      |
# | time/                   |             |
# |    fps                  | 1835        |
# |    iterations           | 29          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.014206761 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.000426    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.8        |
# |    ep_rew_mean          | 0.0547      |
# | time/                   |             |
# |    fps                  | 1832        |
# |    iterations           | 30          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.013991974 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00074     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.5        |
# |    ep_rew_mean          | 0.0698      |
# | time/                   |             |
# |    fps                  | 1825        |
# |    iterations           | 31          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.015863612 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0352     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.000899    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.8        |
# |    ep_rew_mean          | 0.0762      |
# | time/                   |             |
# |    fps                  | 1820        |
# |    iterations           | 32          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.016210854 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0591     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.3        |
# |    ep_rew_mean          | 0.0609      |
# | time/                   |             |
# |    fps                  | 1817        |
# |    iterations           | 33          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.017316204 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.6        |
# |    ep_rew_mean          | 0.027       |
# | time/                   |             |
# |    fps                  | 1815        |
# |    iterations           | 34          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.017831363 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0512     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.8        |
# |    ep_rew_mean          | 0.0853      |
# | time/                   |             |
# |    fps                  | 1812        |
# |    iterations           | 35          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.018363005 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.2        |
# |    ep_rew_mean          | 0.0718      |
# | time/                   |             |
# |    fps                  | 1808        |
# |    iterations           | 36          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.016417796 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95          |
# |    ep_rew_mean          | 0.0537      |
# | time/                   |             |
# |    fps                  | 1805        |
# |    iterations           | 37          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.016439836 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.1        |
# |    ep_rew_mean          | 0.0517      |
# | time/                   |             |
# |    fps                  | 1802        |
# |    iterations           | 38          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.017221631 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0597      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0525     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.5        |
# |    ep_rew_mean          | 0.0974      |
# | time/                   |             |
# |    fps                  | 1796        |
# |    iterations           | 39          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.013716562 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00819    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.9       |
# |    ep_rew_mean          | 0.138      |
# | time/                   |            |
# |    fps                  | 1790       |
# |    iterations           | 40         |
# |    time_elapsed         | 183        |
# |    total_timesteps      | 327680     |
# | train/                  |            |
# |    approx_kl            | 0.01955907 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0257    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0154    |
# |    value_loss           | 0.00187    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.6        |
# |    ep_rew_mean          | 0.0906      |
# | time/                   |             |
# |    fps                  | 1789        |
# |    iterations           | 41          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.017058264 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00369     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 1787        |
# |    iterations           | 42          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.015455771 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000223    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.4        |
# |    ep_rew_mean          | 0.0825      |
# | time/                   |             |
# |    fps                  | 1784        |
# |    iterations           | 43          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.017135149 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0248     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88          |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 1782        |
# |    iterations           | 44          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.015247267 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0392     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.3        |
# |    ep_rew_mean          | 0.122       |
# | time/                   |             |
# |    fps                  | 1781        |
# |    iterations           | 45          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.019285353 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0345     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87.5       |
# |    ep_rew_mean          | 0.13       |
# | time/                   |            |
# |    fps                  | 1780       |
# |    iterations           | 46         |
# |    time_elapsed         | 211        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.01686455 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.514      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00666   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.00245    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.5        |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 47          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.016948394 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 0.0024      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.1        |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 48          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.017574426 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0192      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.00303     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.2        |
# |    ep_rew_mean          | 0.112       |
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 49          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.016943283 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0495     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.00302     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.6        |
# |    ep_rew_mean          | 0.109       |
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 50          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.018515404 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0466     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 51          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.018209793 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.4        |
# |    ep_rew_mean          | 0.0704      |
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 52          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.016398229 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0221     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.00295     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.1       |
# |    ep_rew_mean          | 0.116      |
# | time/                   |            |
# |    fps                  | 1780       |
# |    iterations           | 53         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 434176     |
# | train/                  |            |
# |    approx_kl            | 0.01713716 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.478      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0195    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.017     |
# |    value_loss           | 0.00122    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.7        |
# |    ep_rew_mean          | 0.0984      |
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 54          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.016260633 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0443     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.3       |
# |    ep_rew_mean          | 0.113      |
# | time/                   |            |
# |    fps                  | 1780       |
# |    iterations           | 55         |
# |    time_elapsed         | 253        |
# |    total_timesteps      | 450560     |
# | train/                  |            |
# |    approx_kl            | 0.02251409 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0361     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 0.00223    |
# ----------------------------------------
# ...
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 0.00657     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.8        |
# |    ep_rew_mean          | 0.268       |
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 106         |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.019756027 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0268      |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.0072      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.4        |
# |    ep_rew_mean          | 0.327       |
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 107         |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 876544      |
# | train/                  |             |
# |    approx_kl            | 0.019352429 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 0.00627     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.5        |
# |    ep_rew_mean          | 0.363       |
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 108         |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.018410265 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00765    |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 0.00744     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.7        |
# |    ep_rew_mean          | 0.433       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 109         |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 892928      |
# | train/                  |             |
# |    approx_kl            | 0.022299364 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 0.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | 0.371       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 110         |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.020170476 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.419      |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.7        |
# |    ep_rew_mean          | 0.391       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 111         |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 909312      |
# | train/                  |             |
# |    approx_kl            | 0.019423999 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.004      |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 0.00887     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71.3       |
# |    ep_rew_mean          | 0.306      |
# | time/                   |            |
# |    fps                  | 1764       |
# |    iterations           | 112        |
# |    time_elapsed         | 520        |
# |    total_timesteps      | 917504     |
# | train/                  |            |
# |    approx_kl            | 0.01905876 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.402     |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00889   |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | -0.00848   |
# |    value_loss           | 0.00932    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.9        |
# |    ep_rew_mean          | 0.361       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 113         |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 925696      |
# | train/                  |             |
# |    approx_kl            | 0.020442463 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.382      |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00135    |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 0.00822     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.8        |
# |    ep_rew_mean          | 0.361       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 114         |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.014896806 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0304     |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 0.00688     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.4       |
# |    ep_rew_mean          | 0.409      |
# | time/                   |            |
# |    fps                  | 1764       |
# |    iterations           | 115        |
# |    time_elapsed         | 534        |
# |    total_timesteps      | 942080     |
# | train/                  |            |
# |    approx_kl            | 0.01838309 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.358     |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00103    |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | -0.00697   |
# |    value_loss           | 0.00918    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.8       |
# |    ep_rew_mean          | 0.443      |
# | time/                   |            |
# |    fps                  | 1764       |
# |    iterations           | 116        |
# |    time_elapsed         | 538        |
# |    total_timesteps      | 950272     |
# | train/                  |            |
# |    approx_kl            | 0.02132466 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.355     |
# |    explained_variance   | 0.417      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00419    |
# |    n_updates            | 1150       |
# |    policy_gradient_loss | -0.0077    |
# |    value_loss           | 0.0115     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.8        |
# |    ep_rew_mean          | 0.414       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 117         |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.021722771 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | 0.373       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 118         |
# |    time_elapsed         | 547         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.016689908 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | 0.374       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 119         |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.019048274 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 0.0094      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.5        |
# |    ep_rew_mean          | 0.436       |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 120         |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.019007605 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.00778    |
# |    value_loss           | 0.00972     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.2        |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 1765        |
# |    iterations           | 121         |
# |    time_elapsed         | 561         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.016064882 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.282      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.1        |
# |    ep_rew_mean          | 0.337       |
# | time/                   |             |
# |    fps                  | 1765        |
# |    iterations           | 122         |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.014403652 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00705     |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 0.00909     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.7        |
# |    ep_rew_mean          | 0.388       |
# | time/                   |             |
# |    fps                  | 1765        |
# |    iterations           | 123         |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.015061151 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00817    |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 0.00901     |
# -----------------------------------------

# %%
model3.save("models/ppo_vanilla_four_no_step_cap")

# %%
model3 = PPO.load("models/ppo_vanilla_four_no_step_cap",env=env_vec_four)

mean_reward, std_reward = evaluate_policy(model3, env=env_vec_four, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# Mean Reward: 0.17768 +/- 0.3591202272220266

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_four.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model3.predict(obs)
        obs, reward, done, info = env_vec_four.step(action)
        #print(done)
        total_reward += reward
        env_vec_four.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_four.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.748]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.577]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.604]
# Episode 6: Total Reward = [0.865]
# Episode 7: Total Reward = [0.955]
# Episode 8: Total Reward = [0.307]
# Episode 9: Total Reward = [0.928]
# Episode 10: Total Reward = [0.]
# Episode 11: Total Reward = [0.91]
# Episode 12: Total Reward = [0.883]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.442]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.775]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.757]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.766]
# Episode 22: Total Reward = [0.703]
# Episode 23: Total Reward = [0.127]
# Episode 24: Total Reward = [0.919]
# Episode 25: Total Reward = [0.595]
# Episode 26: Total Reward = [0.838]
# Episode 27: Total Reward = [0.307]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.109]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.82]
# Episode 33: Total Reward = [0.55]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.739]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.766]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.865]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.595]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.775]
# Episode 46: Total Reward = [0.946]
# Episode 47: Total Reward = [0.91]
# Episode 48: Total Reward = [0.748]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.73]
# Average Reward over 50 episodes: [0.43117997]
