# %% [markdown]
# # Vanilla DQN + action wrapper + reward shaping
#
# Run on 3 environments
#
# Empty Room
#
# Empty Room Random
#
# Four Rooms

# %%
import gymnasium as gym
import minigrid
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from minigrid.wrappers import FlatObsWrapper
import time
import numpy as np
from minigrid.core.world_object import Goal
import random
from stable_baselines3.common.callbacks import BaseCallback
from gymnasium.envs.registration import register
from minigrid.core.constants import OBJECT_TO_IDX, IDX_TO_OBJECT, COLOR_TO_IDX, IDX_TO_COLOR, DIR_TO_VEC
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\josep\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # First Empty

# %%
# Create and wrap the environment
env_id = "MiniGrid-Empty-16x16-v0"

# %%
class ActionWrapper(gym.ActionWrapper):
    def __init__(self, env):
        super(ActionWrapper, self).__init__(env)
        # Define a new action space with only the relevant actions
        self.action_space = gym.spaces.Discrete(3)  # Only three actions: left, right, forward

    def action(self, action):
        # Map the new actions to the original actions
        action_mapping = {
            0: 0,  # left
            1: 1,  # right
            2: 2   # forward
        }
        return action_mapping[action]

# %%
class RewardShapingWrapper1(gym.Wrapper):
    def __init__(self, env):
        super(RewardShapingWrapper1, self).__init__(env)
        self.last_action = None
        self.spin_counter = 0  # Tracks consecutive left-right turns

    def step(self, action):
        obs, reward, done, info, extra = self.env.step(action)
        current_pos = self.env.agent_pos

        # Check for spinning behavior
        if self.last_action in [0, 1] and action in [0, 1] and action != self.last_action:
            self.spin_counter += 1
        else:
            self.spin_counter = 0

        if self.spin_counter > 2:  # Threshold for considering it spinning
            reward -= 10
            self.spin_counter = 0  # Reset counter after penalty

        if self.last_action == 0 and action == 1 or self.last_action == 1 and action == 0:
            reward -= 10  # Increase penalty for oscillating between left and right

        self.last_action = action
        return obs, reward, done, info, extra

    def reset(self, **kwargs):
        obs = self.env.reset(**kwargs)
        self.last_action = None
        self.spin_counter = 0
        return obs

    def is_facing_wall(self):
        x, y = self.env.agent_pos
        direction_idx = self.env.agent_dir
        delta = self.env.DIR_TO_VEC[direction_idx]
        next_x, next_y = x + delta[0], y + delta[1]
        if 0 <= next_x < self.env.width and 0 <= next_y < self.env.height:
            next_cell = self.env.grid.get(next_x, next_y)
            return next_cell is not None and next_cell.type == 'wall'
        return False

# %%
class RewardShapingWrapper2(gym.Wrapper):
    def __init__(self, env):
        super(RewardShapingWrapper2, self).__init__(env)
        self.last_action = None
        self.spin_counter = 0  # Tracks consecutive left-right turns
        self.last_distance = None
        self.goal_pos = self.get_goal_position()  # Method to determine goal position

    def step(self, action):
        obs, reward, done, info,extra = self.env.step(action)
        #print(f"Observation: {obs}")
        current_pos = self.env.agent_pos
        
        # Calculate distance to the goal
        if self.last_distance is None:
            self.last_distance = self.calculate_distance(current_pos, self.goal_pos)
            #print("distance to goal",self.last_distance)

        new_distance = self.calculate_distance(current_pos, self.goal_pos)
        if new_distance < self.last_distance:
            # Reward for moving closer to the goal
            reward += 5 * (self.last_distance - new_distance)
        self.last_distance = new_distance

        if action == 2 and self.is_facing_wall():
            reward -= 10  # Penalty for trying to move into a wall

        # Check for spinning behavior
        if self.last_action in [0, 1] and action in [0, 1] and action != self.last_action:
            self.spin_counter += 1
        else:
            self.spin_counter = 0

        if self.spin_counter > 2:  # Threshold for considering it spinning
            reward -= 10
            self.spin_counter = 0  # Reset counter after penalty

        #dditional logic to discourage spinning or other suboptimal behaviors
        if self.last_action == 0 and action == 1 or self.last_action == 1 and action == 0:
            reward -= 10  # Increase penalty for oscillating between left and right

        # High terminal reward when reaching the goal
        if np.array_equal(current_pos, self.goal_pos):
            reward += 500  # High reward for reaching the goal
            done = True

        self.last_action = action
        return obs, reward, done, info,extra

    
    def reset(self, **kwargs):  # Accept any additional keyword arguments
        obs = self.env.reset(**kwargs)  # Reset the underlying environment
        self.goal_pos = self.env.get_goal_position()  # Retrieve the updated goal position
        self.last_distance = None
        self.last_action = None
        #self.spin_counter = 0
        return obs  # Return the observation

    def calculate_distance(self, current_pos, goal_pos):
        if current_pos is None or goal_pos is None:
            return float('inf')  # Return a large distance if any position is not initialized
        dist_to_goal = np.linalg.norm(np.array(current_pos) - np.array(goal_pos))
        #print('distance to goal:', dist_to_goal)
        return dist_to_goal

    def is_facing_wall(self):
        x, y = self.env.agent_pos
        direction_idx = self.env.agent_dir
        delta = DIR_TO_VEC[direction_idx]
        next_x, next_y = x + delta[0], y + delta[1]
        if 0 <= next_x < self.env.width and 0 <= next_y < self.env.height:
            next_cell = self.env.grid.get(next_x, next_y)
            #print("Object to Index Mapping:", OBJECT_TO_IDX)
            #print("Index for goal:", OBJECT_TO_IDX['goal'])
            #print("Index for wall:", OBJECT_TO_IDX['wall'])
            return next_cell and next_cell.type == OBJECT_TO_IDX['wall']
        return False

# %%
class RewardShapingWrapper3(gym.Wrapper):
    def __init__(self, env):
        super(RewardShapingWrapper3, self).__init__(env)
        self.last_pos = None
        self.goal_pos = None
        self.stuck_counter = 0

    def step(self, action):
        action = self.noisy_action(action)  # Apply noise to the action for exploration
        obs, reward, done, info, extra = self.env.step(action)
        current_pos = self.env.agent_pos

        if self.goal_pos is None:
            self.goal_pos = self.get_goal_position()

        current_room = self.get_room(current_pos)
        last_room = self.get_room(self.last_pos) if self.last_pos else None

        # Check if transitioned to a new room
        if last_room and current_room and last_room != current_room:
            reward += 5.0  # Reward for moving to a new room

        # Additional vector to the nearest gap or doorway
        nearest_gap_vector = self.get_vector_to_nearest_gap(current_pos)
        obs['nearest_gap_direction'] = nearest_gap_vector  # Ensure obs is a dictionary

        # Assuming obs is a dictionary that includes 'image' and possibly other keys
        goal_direction = self.get_goal_direction(current_pos)
        # If you intend to add goal_direction to obs, you should add it as a new key-value pair
        obs['goal_direction'] = goal_direction  # Add it like this if obs is a dictionary

        # Reward shaping calculations
        if self.last_pos is not None and self.goal_pos is not None:
            distance_reward = self.calculate_reward_shaping(current_pos)
            additional_reward = self.additional_rewards(action, current_pos, self.last_pos)
            reward += distance_reward + additional_reward

        if np.array_equal(current_pos, self.goal_pos):
            reward += 100
            done = True

        if self.last_pos == current_pos:
            self.stuck_counter += 1
        else:
            self.stuck_counter = 0

        if self.stuck_counter > 3:
            obs = self.nudge_agent(current_pos) or obs
            self.stuck_counter = 0

        self.last_pos = current_pos
        return obs, reward, done, info, extra

    def reset(self, **kwargs):
        obs = self.env.reset(**kwargs)
        self.last_pos = self.env.agent_pos
        self.goal_pos = self.get_goal_position()
        self.gaps = self.find_gaps()  # Find gaps upon reset
        return obs
    
    def get_vector_to_nearest_gap(self, current_pos):
        if not self.gaps:
            return np.zeros(2)  # Default to zero vector if no gaps identified

        nearest_gap = min(self.gaps, key=lambda gap: np.linalg.norm(np.array(gap) - np.array(current_pos)))
        direction_vector = np.array(nearest_gap) - np.array(current_pos)
        norm = np.linalg.norm(direction_vector)
        return direction_vector / norm if norm != 0 else direction_vector

    
    def find_gaps(self):
        width, height = self.env.width, self.env.height
        gaps = []
        # Typically, gaps will be in the walls that divide the rooms
        # We scan horizontal and vertical mid-lines for empty spaces
        mid_vertical = width // 2
        mid_horizontal = height // 2

        # Vertical mid-line (check for empty cells)
        for y in range(height):
            if self.env.grid.get(mid_vertical, y) is None:
                #print('vertical', self.env.grid.get(mid_vertical, y))
                #print('the gap vertical mid-line is',(mid_vertical, y) )
                gaps.append((mid_vertical, y))

        # Horizontal mid-line (check for empty cells)
        for x in range(width):
            if self.env.grid.get(x, mid_horizontal) is None:
                gaps.append((x, mid_horizontal))

        return gaps


    def get_goal_position(self):
        for x in range(self.env.width):
            for y in range(self.env.height):
                if self.env.grid.get(x, y) is not None and isinstance(self.env.grid.get(x, y), Goal):
                    return (x, y)
        return None
    
    
    def calculate_reward_shaping(self, current_pos):
        if not self.goal_pos:
            return 0
        
        epsilon = 0.01  # Small value to avoid division by zero
        prev_distance = np.linalg.norm(np.array(self.last_pos) - np.array(self.goal_pos))
        current_distance = np.linalg.norm(np.array(current_pos) - np.array(self.goal_pos))
        
        if current_distance < prev_distance:
            return 0.1 * (1 / (current_distance + epsilon))
        elif current_distance > prev_distance:
            return -0.1 * (1 / (current_distance + epsilon))
        return 0

    def additional_rewards(self, action, current_pos, prev_pos):
        prev_distance = np.linalg.norm(np.array(prev_pos) - np.array(self.goal_pos))
        current_distance = np.linalg.norm(np.array(current_pos) - np.array(self.goal_pos))
        distance_change = prev_distance - current_distance
        
        if action in [0, 1] and distance_change <= 0:
            return -0.05  # Unchanged, penalty for non-improvement
        
        reward = 0
        if action == 2 and distance_change > 0:
            reward = min(0.05 * distance_change, 1.0)  # Cap the reward to avoid excessively high values

        return reward
    

    def get_goal_direction(self, current_pos):
        if not self.goal_pos:
            return np.zeros_like(current_pos)  # Return a zero vector if goal position is not set
        # Assuming current_pos and goal_pos are numpy arrays or can be converted to them
        direction_vector = np.array(self.goal_pos) - np.array(current_pos)
        # Normalize the vector
        norm = np.linalg.norm(direction_vector)
        if norm == 0:
            return direction_vector  # Avoid division by zero if already at the goal
        return direction_vector / norm
    
    def noisy_action(self, action):
        # Add random noise to the action occasionally
        if random.random() < 0.1:  # With 10% probability, alter the action randomly
            return random.choice([0, 1, 2])  # Assuming actions are 0, 1, 2
        return action
    

    def get_possible_moves(self, current_pos):
        moves = []
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Directions: up, down, left, right

        for dx, dy in directions:
            new_pos = (current_pos[0] + dx, current_pos[1] + dy)
            if self.is_position_valid(new_pos):
                moves.append(new_pos)
        return moves

    def is_position_valid(self, pos):
        x, y = pos
        # Check if within grid bounds
        if 0 <= x < self.env.width and 0 <= y < self.env.height:
            # Check if the cell is empty (None means empty in MiniGrid)
            return self.env.grid.get(x, y) is None
        return False
    
    def nudge_agent(self, current_pos):
        possible_moves = self.get_possible_moves(current_pos)
        if possible_moves:
            new_pos = random.choice(possible_moves)
            self.env.agent_pos = new_pos  # Assuming you can set the position
            # Simulate a no-op or a neutral action to update state and get observation
            obs, _, _, _, _ = self.env.step(0)  # Consider '0' as a no-op action, if applicable
            return obs
        # If no moves are possible or other issues arise, return a default observation
        return np.zeros(self.env.observation_space.shape)  # Adjust based on the specific obs space
    
    def get_room(self, position):
        x, y = position
        if x < 10 and y < 10:
            return 1  # Top-left room
        elif x >= 10 and y < 10:
            return 2  # Top-right room
        elif x < 10 and y >= 10:
            return 3  # Bottom-left room
        elif x >= 10 and y >= 10:
            return 4  # Bottom-right room
        return 0  # Should not happen unless position is out of expected range

# %%
def create_env():
    env = gym.make(env_id, render_mode="rgb_array",max_episode_steps=200)
    env = ActionWrapper(env)
    env = RewardShapingWrapper1(env)
    env = FlatObsWrapper(env)  
    return env

# Use the function in make_vec_env
env_vec = make_vec_env(create_env, n_envs=1)
env_vec2 = make_vec_env(create_env, n_envs=4)

# %%
model = DQN("MlpPolicy", env_vec2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnrewardrand/"
            )

# Train the model
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnrewardrand/DQN_2
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_pos to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pos` for environment variables or `env.get_wrapper_attr('agent_pos')` that will search the reminding wrappers.
#   logger.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -442     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1455     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.74     |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -398     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1349     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.05     |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -390     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1250     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -394     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -384     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1251     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | -365     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1257     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.913    |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -346     |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1270     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04     |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -321     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1264     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.889    |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -304     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1268     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -287     |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1266     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -279     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1264     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.05     |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -267     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1255     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.895    |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -260     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1242     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 10232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 633      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -247     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1234     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11024    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 682      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -238     |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1217     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 11824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1212     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 12280    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.307    |
# |    n_updates        | 761      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | -217     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1200     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.594    |
# |    n_updates        | 809      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1192     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 13568    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 841      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1188     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 14368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.312    |
# |    n_updates        | 891      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1181     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 15168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 941      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1171     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 15844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 984      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1168     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 16216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.598    |
# |    n_updates        | 1007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1164     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 16964    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.88     |
# |    n_updates        | 1054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.176    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1164     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 17348    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 1078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1160     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17776    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 1104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1159     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.859    |
# |    n_updates        | 1121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1148     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 18836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 1171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.0878   |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1148     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.578    |
# |    n_updates        | 1194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -95.9    |
# |    exploration_rate | 0.077    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1148     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.591    |
# |    n_updates        | 1208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.0502   |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1148     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 19996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.583    |
# |    n_updates        | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -71.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1145     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 20536    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 1277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -62      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1144     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 21040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 1308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -56.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1138     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 21732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.584    |
# |    n_updates        | 1352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -48.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1134     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 22036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.578    |
# |    n_updates        | 1371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | -42.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1130     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 22572    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.58     |
# |    n_updates        | 1404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | -36.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1127     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 23372    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.579    |
# |    n_updates        | 1454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | -31      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1124     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24172    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 1504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -23      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1124     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0
    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -2.59    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1948     |
# |    fps              | 1064     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 198308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 12388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -2.61    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1952     |
# |    fps              | 1064     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 199108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000234 |
# |    n_updates        | 12438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -2.61    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1956     |
# |    fps              | 1065     |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 199748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 12478    |
# ----------------------------------

# %%
model.save("dqn_reward_empty")

# %%
model = DQN.load("dqn_reward_empty",env=env_vec,tensorboard_log="./dqnrewardrand/")

mean_reward, std_reward = evaluate_policy(model, env=env_vec, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_pos to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pos` for environment variables or `env.get_wrapper_attr('agent_pos')` that will search the reminding wrappers.
#   logger.warn(
# Mean Reward: 0.0 +/- 0.0

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env_vec.step(action)
        #print(done)
        total_reward += reward
        env_vec.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.8901367]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.9727539]
# Episode 7: Total Reward = [0.92441404]
# Episode 8: Total Reward = [0.92089844]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.9727539]
# Episode 11: Total Reward = [0.9296875]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.8892578]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.8901367]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [-9.080859]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.9578125]
# Episode 21: Total Reward = [0.9015625]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.96132815]
# Episode 24: Total Reward = [0.8989258]
# Episode 25: Total Reward = [0.9604492]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.93056643]
# Episode 28: Total Reward = [-9.047461]
# Episode 29: Total Reward = [0.86992186]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.96308595]
# Episode 32: Total Reward = [0.8901367]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.9692383]
# Episode 36: Total Reward = [0.91738284]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.9314453]
# Episode 42: Total Reward = [0.9753906]
# Episode 43: Total Reward = [0.9507812]
# Episode 44: Total Reward = [0.9472656]
# Episode 45: Total Reward = [-9.030762]
# Episode 46: Total Reward = [0.]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.9727539]
# Average Reward over 50 episodes: [-0.09541992]

# %% [markdown]
# # Empty random room

# %%
register(
    id='custom_empty-v0',
    entry_point='emptyrandom:RandomGoalEmptyEnv',
    kwargs={}
)

# %%
#gym.pprint_registry()  # to see all registered environments

if 'custom_empty-v0' in gym.envs.registry:
    print("Environment 'custom_empty-v0' is registered.")
else:
    print("Environment 'custom_empty-v0' is NOT registered.")
# Out:
# Environment 'custom_empty-v0' is registered.

# %%
env_id2 = 'custom_empty-v0'
def create_env():
    env = gym.make(env_id2, render_mode="rgb_array",size=16,max_episode_steps=200)
    env = ActionWrapper(env)
    env = RewardShapingWrapper2(env)
    env = FlatObsWrapper(env)  
    return env

env_vec_ran = make_vec_env(create_env, n_envs=1)
env_vec_ran2 = make_vec_env(create_env, n_envs=4)
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_goal_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_goal_position` for environment variables or `env.get_wrapper_attr('get_goal_position')` that will search the reminding wrappers.
#   logger.warn(

# %%
# Initialize the DQN model
model2 = DQN("MlpPolicy", env_vec_ran2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnrewardrandempty/"
            )

# Train the model
model2.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnrewardrandempty/DQN_1
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_goal_position to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_goal_position` for environment variables or `env.get_wrapper_attr('get_goal_position')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_pos to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pos` for environment variables or `env.get_wrapper_attr('agent_pos')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.agent_dir to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_dir` for environment variables or `env.get_wrapper_attr('agent_dir')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.width to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.width` for environment variables or `env.get_wrapper_attr('width')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.height to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.height` for environment variables or `env.get_wrapper_attr('height')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\josep\anaconda3\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.grid to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.grid` for environment variables or `env.get_wrapper_attr('grid')` that will search the reminding wrappers.
#   logger.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1066     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.1      |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19     |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1093     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.06     |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1129     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1146     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1139     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -75.2    |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1146     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      |
|
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3340     |
# |    fps              | 1050     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 198060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 12372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.8     |
# |    ep_rew_mean      | 498      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3344     |
# |    fps              | 1050     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 198312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 12388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.4     |
# |    ep_rew_mean      | 497      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3348     |
# |    fps              | 1050     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 198376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.45     |
# |    n_updates        | 12392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 491      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3352     |
# |    fps              | 1050     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 198540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.9     |
# |    n_updates        | 12402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 494      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3356     |
# |    fps              | 1050     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 198776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.802    |
# |    n_updates        | 12417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.5     |
# |    ep_rew_mean      | 492      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3360     |
# |    fps              | 1050     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 199012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.2     |
# |    n_updates        | 12432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.8     |
# |    ep_rew_mean      | 503      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3364     |
# |    fps              | 1050     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 199204   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.1     |
# |    n_updates        | 12444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50.3     |
# |    ep_rew_mean      | 498      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3368     |
# |    fps              | 1050     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 199412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 12457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.7     |
# |    ep_rew_mean      | 497      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3372     |
# |    fps              | 1050     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 199464   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 16.8     |
# |    n_updates        | 12460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.9     |
# |    ep_rew_mean      | 495      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3376     |
# |    fps              | 1050     |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 199812   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.22     |
# |    n_updates        | 12482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.5     |
# |    ep_rew_mean      | 498      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3380     |
# |    fps              | 1050     |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 199928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.3     |
# |    n_updates        | 12489    |
# ----------------------------------

# %%
model2.save("dqn_reward_empty_ran")

# %%
model2 = DQN.load("dqn_reward_empty_ran",env=env_vec_ran,tensorboard_log="./dqnrewardrandempty/")

mean_reward, std_reward = evaluate_policy(model2, env=env_vec_ran, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 4.79GB
#   warnings.warn(
# Mean Reward: 437.69339864 +/- 198.2545935499547

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_ran.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model2.predict(obs)
        obs, reward, done, info = env_vec_ran.step(action)
        #print(done)
        total_reward += reward
        env_vec_ran.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_ran.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [526.4231]
# Episode 2: Total Reward = [557.40027]
# Episode 3: Total Reward = [576.0323]
# Episode 4: Total Reward = [640.2158]
# Episode 5: Total Reward = [580.4591]
# Episode 6: Total Reward = [557.3975]
# Episode 7: Total Reward = [536.2653]
# Episode 8: Total Reward = [61.391777]
# Episode 9: Total Reward = [561.83276]
# Episode 10: Total Reward = [535.928]
# Episode 11: Total Reward = [32.111023]
# Episode 12: Total Reward = [572.22614]
# Episode 13: Total Reward = [627.6891]
# Episode 14: Total Reward = [523.8772]
# Episode 15: Total Reward = [159.00934]
# Episode 16: Total Reward = [23.033628]
# Episode 17: Total Reward = [-83.6429]
# Episode 18: Total Reward = [104.32257]
# Episode 19: Total Reward = [569.9144]
# Episode 20: Total Reward = [109.1703]
# Episode 21: Total Reward = [584.1961]
# Episode 22: Total Reward = [579.50616]
# Episode 23: Total Reward = [540.3355]
# Episode 24: Total Reward = [516.7574]
# Episode 25: Total Reward = [560.5838]
# Episode 26: Total Reward = [565.55304]
# Episode 27: Total Reward = [49.669075]
# Episode 28: Total Reward = [530.937]
# Episode 29: Total Reward = [564.8422]
# Episode 30: Total Reward = [572.47095]
# Episode 31: Total Reward = [567.51166]
# Episode 32: Total Reward = [122.698524]
# Episode 33: Total Reward = [557.2596]
# Episode 34: Total Reward = [612.11255]
# Episode 35: Total Reward = [578.4149]
# Episode 36: Total Reward = [559.3243]
# Episode 37: Total Reward = [586.97046]
# Episode 38: Total Reward = [-415.12762]
# Episode 39: Total Reward = [587.70276]
# Episode 40: Total Reward = [579.19965]
# Episode 41: Total Reward = [520.95496]
# Episode 42: Total Reward = [516.7484]
# Episode 43: Total Reward = [122.32198]
# Episode 44: Total Reward = [33.305523]
# Episode 45: Total Reward = [104.83758]
# Episode 46: Total Reward = [566.91345]
# Episode 47: Total Reward = [2.0500515]
# Episode 48: Total Reward = [586.9527]
# Episode 49: Total Reward = [89.46995]
# Episode 50: Total Reward = [612.8811]
# Average Reward over 50 episodes: [406.5682]

# %% [markdown]
# # Now Four rooms

# %%
env_id3 = "MiniGrid-FourRooms-v0"
def create_env():
    env = gym.make(env_id3, render_mode="rgb_array")
    env = ActionWrapper(env)
    env = RewardShapingWrapper3(env)
    env = FlatObsWrapper(env)  
    return env

env_vec_four = make_vec_env(create_env, n_envs=1)
env_vec_four2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model3 = DQN("MlpPolicy", env_vec_four2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnrewardfour/"
            )

# Train the model
model3.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# Logging to ./dqnrewardfour/DQN_2
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 4.65GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.8     |
# |    ep_rew_mean      | -2.17    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1028     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 344      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00159  |
# |    n_updates        | 15       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.2     |
# |    ep_rew_mean      | -2.3     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1039     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 680      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000397 |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.2     |
# |    ep_rew_mean      | -2.32    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1038     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000305 |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | -2.34    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1027     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1352     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000397 |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.8     |
# |    ep_rew_mean      | -2.16    |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1007     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1684     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000302 |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | -2.14    |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1015     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2020     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000434 |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.1     |
# |    ep_rew_mean      | -2.16    |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1020     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2356     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000268 |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.7     |
# |    ep_rew_mean      | -2.19    |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1024     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2692     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000746 |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.9     |
# |    ep_rew_mean      | -2.13    |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1017     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2936     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000391 |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.4     |
# |    ep_rew_mean      | 0.388    |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1023     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3216     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000348 |
# |    n_updates        | 194      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.1     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1025     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3552     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000406 |
# |    n_updates        | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -0.0557  |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1028     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3888     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000452 |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | -0.228   |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1027     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4224     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000401 |
# |    n_updates        | 257      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.6     |
# |    ep_rew_mean      | -0.283   |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1030     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4560     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000361 |
# |    n_updates        | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.6     |
# |    ep_rew_mean      | -0.343   |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1029     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4720     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000506 |
# |    n_updates        | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78       |
# |    ep_rew_mean      | -0.472   |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1031     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5056     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000377 |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -0.55    |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1032     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000303 |
# |    n_updates        | 330      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.9     |
# |    ep_rew_mean      | -0.605   |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1032     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000299 |
# |    n_updates        | 345      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.2     |
# |    ep_rew_mean      | -0.704   |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1035     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5964     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000277 |
# |    n_updates        | 366      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.6     |
# |    ep_rew_mean      | -0.77    |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1022     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6300     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000539 |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.3     |
# |    ep_rew_mean      | -0.816   |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1017     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000469 |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.6     |
# |    ep_rew_mean      | -0.878   |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1018     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6932     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000408 |
# |    n_updates        | 427      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.9     |
# |    ep_rew_mean      | -0.935   |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000459 |
# |    n_updates        | 1191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -0.564   |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 998      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 19500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000339 |
# |    n_updates        | 1212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -0.566   |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 998      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 19836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000207 |
# |    n_updates        | 1233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -0.459   |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 998      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 20172    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 1254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -0.399   |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 999      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 20508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000238 |
# |    n_updates        | 1275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -0.442   |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 997      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 20844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000457 |
# |    n_updates        | 1296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.4     |
# |    ep_rew_mean      | -0.411   |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 998      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 21180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.71e-05 |
# |    n_updates        | 1317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | -0.508   |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 997      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 21516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000208 |
# |    n_updates        | 1338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | -0.549   |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 997      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 21852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000112 |
# |    n_updates        | 1359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | -0.527   |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 997      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 22188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 1380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | -0.424   |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 997      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 22524    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000233 |
# |    n_updates        | 1401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | -1.46    |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 998      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 22860    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00059  |
# |    n_updates        | 1422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | -1.45    |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 997      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 23196    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000307 |
# |    n_updates        | 1443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.41    |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 996      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 23480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000552 |
# |    n_updates        | 1461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.41    |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 995      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 23816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000646 |
# |    n_updates        | 1482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.35    |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 995      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 24152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00022  |
# |    n_updates        | 1503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.34    |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 996      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 24488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 1524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.38    |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 993      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 24824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000362 |
# |    n_updates        | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | -1.37    |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 993      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 25160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000302 |
# |    n_updates        | 1566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | -1.35    |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 992      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 25496    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00476  |
# |    n_updates        | 1587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | -1.39    |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 991      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 25832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -1.38    |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 992      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 26168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000296 |
# |    n_updates        | 1629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -1.28    |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 993      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 26504    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000381 |
# |    n_updates        | 1650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -1.25    |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 994      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 26840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 1671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -1.24    |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 994      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 27176    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000334 |
# |    n_updates        | 1692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.14    |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 993      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 27392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000255 |
# |    n_updates        | 1705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.13    |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 993      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 27728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 1726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.12    |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 993      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 28064    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000366 |
# |    n_updates        | 1747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -1.03    |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 993      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 28400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000208 |
# |    n_updates        | 1768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | -1.18    |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 993      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 28736    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000311 |
# |    n_updates        | 1789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | -1.18    |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 993      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 29072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000301 |
# |    n_updates        | 1810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.4     |
# |    ep_rew_mean      | -1.18    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 993      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 29408    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000265 |
# ...
# |    time_elapsed     | 1165     |
# |    total_timesteps  | 991956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 61991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 0.812    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14476    |
# |    fps              | 851      |
# |    time_elapsed     | 1165     |
# |    total_timesteps  | 992192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000744 |
# |    n_updates        | 62005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.2     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14480    |
# |    fps              | 851      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 992376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000361 |
# |    n_updates        | 62017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.6     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14484    |
# |    fps              | 851      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 992636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000229 |
# |    n_updates        | 62033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 0.933    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14488    |
# |    fps              | 851      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 992880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000355 |
# |    n_updates        | 62048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.7     |
# |    ep_rew_mean      | 0.931    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14492    |
# |    fps              | 851      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 993148   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000239 |
# |    n_updates        | 62065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.9     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14496    |
# |    fps              | 851      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 993356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000711 |
# |    n_updates        | 62078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14500    |
# |    fps              | 851      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 993648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 62096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | 1.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14504    |
# |    fps              | 851      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 993984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00221  |
# |    n_updates        | 62117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.5     |
# |    ep_rew_mean      | 1.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14508    |
# |    fps              | 851      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 994156   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00182  |
# |    n_updates        | 62128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.5     |
# |    ep_rew_mean      | 1.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14512    |
# |    fps              | 851      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 994316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000206 |
# |    n_updates        | 62138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.7     |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14516    |
# |    fps              | 851      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 994524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000652 |
# |    n_updates        | 62151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.1     |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14520    |
# |    fps              | 851      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 994860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000309 |
# |    n_updates        | 62172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63       |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14524    |
# |    fps              | 851      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 995164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000629 |
# |    n_updates        | 62191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.2     |
# |    ep_rew_mean      | 1.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14528    |
# |    fps              | 850      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 995500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00112  |
# |    n_updates        | 62212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.9     |
# |    ep_rew_mean      | 1.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14532    |
# |    fps              | 850      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 995836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000802 |
# |    n_updates        | 62233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.9     |
# |    ep_rew_mean      | 1.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14536    |
# |    fps              | 850      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 996172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00016  |
# |    n_updates        | 62254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.7     |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14540    |
# |    fps              | 850      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 996440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000774 |
# |    n_updates        | 62271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.5     |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14544    |
# |    fps              | 850      |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 996772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 62292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.9     |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14548    |
# |    fps              | 850      |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 997108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000377 |
# |    n_updates        | 62313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.3     |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14552    |
# |    fps              | 850      |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 997392   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000956 |
# |    n_updates        | 62330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.1     |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14556    |
# |    fps              | 850      |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 997728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000248 |
# |    n_updates        | 62351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 1.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14560    |
# |    fps              | 850      |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 997964   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00028  |
# |    n_updates        | 62366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 1.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14564    |
# |    fps              | 850      |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 998068   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 62373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 1.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14568    |
# |    fps              | 850      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 998404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000382 |
# |    n_updates        | 62394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14572    |
# |    fps              | 850      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 998560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 62403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14576    |
# |    fps              | 850      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 998828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000203 |
# |    n_updates        | 62420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.8     |
# |    ep_rew_mean      | 1.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14580    |
# |    fps              | 850      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 999164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000531 |
# |    n_updates        | 62441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.3     |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14584    |
# |    fps              | 850      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 999500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000247 |
# |    n_updates        | 62462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.3     |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14588    |
# |    fps              | 850      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 999744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 62477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.9     |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 14592    |
# |    fps              | 850      |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 999944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000451 |
# |    n_updates        | 62490    |
# ----------------------------------

# %%
model3.save("dqn_reward_four")

# %%
model3 = DQN.load("dqn_reward_four",env=env_vec_four,tensorboard_log="./dqnrewardfour/")

mean_reward, std_reward = evaluate_policy(model3, env=env_vec_four, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 0.23GB
#   warnings.warn(
# Mean Reward: 0.4895082 +/- 1.1690605222019943

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_four.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model3.predict(obs)
        obs, reward, done, info = env_vec_four.step(action)
        #print(done)
        total_reward += reward
        env_vec_four.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_four.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [-0.38729355]
# Episode 2: Total Reward = [-0.07023036]
# Episode 3: Total Reward = [-0.37541193]
# Episode 4: Total Reward = [0.49189624]
# Episode 5: Total Reward = [0.03009739]
# Episode 6: Total Reward = [0.52255654]
# Episode 7: Total Reward = [-0.44386178]
# Episode 8: Total Reward = [-0.20010193]
# Episode 9: Total Reward = [-0.05612034]
# Episode 10: Total Reward = [-0.00029896]
# Episode 11: Total Reward = [-0.20032798]
# Episode 12: Total Reward = [0.07328919]
# Episode 13: Total Reward = [-0.29448465]
# Episode 14: Total Reward = [-0.32154104]
# Episode 15: Total Reward = [0.03803198]
# Episode 16: Total Reward = [-0.30327803]
# Episode 17: Total Reward = [-0.21098684]
# Episode 18: Total Reward = [0.14747807]
# Episode 19: Total Reward = [-0.5880928]
# Episode 20: Total Reward = [-0.15970244]
# Episode 21: Total Reward = [-0.2416734]
# Episode 22: Total Reward = [-0.19814318]
# Episode 23: Total Reward = [9.918353]
# Episode 24: Total Reward = [5.2451687]
# Episode 25: Total Reward = [-0.38027927]
# Episode 26: Total Reward = [-0.16784672]
# Episode 27: Total Reward = [0.81931823]
# Episode 28: Total Reward = [4.6217985]
# Episode 29: Total Reward = [0.991]
# Episode 30: Total Reward = [-0.11521465]
# Episode 31: Total Reward = [-0.10902482]
# Episode 32: Total Reward = [0.94781333]
# Episode 33: Total Reward = [4.31992]
# Episode 34: Total Reward = [0.07515558]
# Episode 35: Total Reward = [0.80521196]
# Episode 36: Total Reward = [0.959868]
# Episode 37: Total Reward = [-0.16252327]
# Episode 38: Total Reward = [-0.0984699]
# Episode 39: Total Reward = [-0.16891095]
# Episode 40: Total Reward = [0.5517092]
# Episode 41: Total Reward = [-0.02852781]
# Episode 42: Total Reward = [-0.02915806]
# Episode 43: Total Reward = [0.991]
# Episode 44: Total Reward = [0.24374376]
# Episode 45: Total Reward = [-0.42997319]
# Episode 46: Total Reward = [0.70159936]
# Episode 47: Total Reward = [-0.23705831]
# Episode 48: Total Reward = [0.02259045]
# Episode 49: Total Reward = [0.1298565]
# Episode 50: Total Reward = [0.17952448]
# Average Reward over 50 episodes: [0.5369688]
