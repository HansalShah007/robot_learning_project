# %% [markdown]
# # Vanilla DQN - with ActionWrapper
#
# Run on 3 environments
#
# Empty Room
#
# Empty Room Random
#
# Four Rooms

# %%
import gymnasium as gym
import minigrid
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from minigrid.wrappers import FlatObsWrapper
import time
import numpy as np
from minigrid.core.world_object import Goal
import random
from stable_baselines3.common.callbacks import BaseCallback
from gymnasium.envs.registration import register
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\josep\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # First Empty

# %%
# Create and wrap the environment
env_id = "MiniGrid-Empty-16x16-v0"

# %%
class ActionWrapper(gym.ActionWrapper):
    def __init__(self, env):
        super(ActionWrapper, self).__init__(env)
        # Define a new action space with only the relevant actions
        self.action_space = gym.spaces.Discrete(3)  # Only three actions: left, right, forward

    def action(self, action):
        # Map the new actions to the original actions
        action_mapping = {
            0: 0,  # left
            1: 1,  # right
            2: 2   # forward
        }
        return action_mapping[action]

# %%
def create_env():
    env = gym.make(env_id, render_mode="rgb_array",max_episode_steps=200)
    env = ActionWrapper(env)
    env = FlatObsWrapper(env)  
    return env

# Use the function in make_vec_env
env_vec = make_vec_env(create_env, n_envs=1)
env_vec2 = make_vec_env(create_env, n_envs=4)

# %%
model = DQN("MlpPolicy", env_vec2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnactionrand/"
            )

# Train the model
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnactionrand/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1418     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000129 |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1385     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.54e-05 |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1385     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.2e-05  |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1378     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.69e-05 |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1363     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.83e-05 |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1355     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.6e-05  |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1327     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.93e-05 |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1268     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.47e-05 |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1232     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.74e-05 |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0.0207   |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1203     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.75e-05 |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0.0188   |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1154     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08e-05 |
# |    n_updates        | 543      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0.0172   |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1108     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2e-05  |
# |    n_updates        | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0337   |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1087     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.97e-05 |
# |    n_updates        | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0313   |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1054     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.65e-05 |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0292   |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 838      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.08e-05 |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0405   |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 813      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17e-05 |
# |    n_updates        | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0381   |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 808      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56e-05 |
# |    n_updates        | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 0.0593   |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 810      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.15e-05 |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0676   |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 819      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.97e-05 |
# |    n_updates        | 943      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0642   |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 828      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98e-05 |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0717   |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 832      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.13e-05 |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0684   |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 839      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.86e-05 |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0655   |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 838      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11e-05 |
# |    n_updates        | 1143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0627   |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 843      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.03e-05 |
# |    n_updates        | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0698   |
# |    exploration_rate | 0.0547   |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 850      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19900    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.52e-05 |
# |    n_updates        | 1237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0698   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 857      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 20700    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81e-05 |
# |    n_updates        | 1287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0964   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 861      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 21232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.73e-05 |
# |    n_updates        | 1320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 0.133    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 861      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 21476    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.57e-05 |
# |    n_updates        | 1336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 864      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 21800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35e-05 |
# |    n_updates        | 1356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 0.206    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 868      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 22200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72e-05 |
# |    n_updates        | 1381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 0.253    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 871      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 22528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.98e-05 |
# |    n_updates        | 1401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 873      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 22972    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72e-05 |
# |    n_updates        | 1429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | 0.317    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 874      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 23256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88e-05 |
# |    n_updates        | 1447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 0.353    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 878      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 23728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1e-05    |
# |    n_updates        | 1476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 882      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 24336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000158 |
# |    n_updates        | 1514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 0.407    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 887      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 24964    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.78e-05 |
# |    n_updates        | 1554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 0.442    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 891      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 25336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000244 |
# |    n_updates        | 1577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 0.442    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 897      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 26136    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-06 |
# |    n_updates        | 1627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 0.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 902      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 26704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.65e-05 |
# |    n_updates        | 1662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      
     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 0.0903   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1000     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 58592    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17e-05 |
# |    n_updates        | 3655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 0.0903   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1001     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 59392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52e-05 |
# |    n_updates        | 3705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 0.0903   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1002     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 60192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.16e-05 |
# |    n_updates        | 3755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 0.0896   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1003     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 60828    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00042  |
# |    n_updates        | 3795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 0.0989   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1004     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 61524    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.99e-05 |
# |    n_updates        | 3839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 0.126    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1005     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 62276    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000142 |
# |    n_updates        | 3886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 0.134    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1005     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 63076    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000227 |
# |    n_updates        | 3936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 0.126    |
# |    exploration_rate | 0.05     |
# ...
# |    time_elapsed     | 165      |
# |    total_timesteps  | 176128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.46e-05 |
# |    n_updates        | 11001    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 0.161    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 1064     |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 176928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000185 |
# |    n_updates        | 11051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 0.143    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 1064     |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 177728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00011  |
# |    n_updates        | 11101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 0.116    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 1064     |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 178528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.61e-05 |
# |    n_updates        | 11151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 0.108    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 1064     |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 179328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00409  |
# |    n_updates        | 11201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 0.0986   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 1065     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 180128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 11251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 0.0814   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 1065     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 180928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000113 |
# |    n_updates        | 11301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 0.0814   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 1065     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 181728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5e-05    |
# |    n_updates        | 11351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 0.0814   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 1065     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 182528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00437  |
# |    n_updates        | 11401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 0.0731   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 1065     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 183328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 11451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0641   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 1065     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 184128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.38e-05 |
# |    n_updates        | 11501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0724   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 1065     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 184928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.96e-05 |
# |    n_updates        | 11551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0724   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 1065     |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 185728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 11601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0724   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 1066     |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 186528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0051   |
# |    n_updates        | 11651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0724   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 1066     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 187328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 11701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0724   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 1066     |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 188128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00427  |
# |    n_updates        | 11751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0638   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 1065     |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 188928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000102 |
# |    n_updates        | 11801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0638   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 1065     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 189728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000149 |
# |    n_updates        | 11851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0638   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 1065     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 190528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 11901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 0.0638   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 1065     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 191328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000282 |
# |    n_updates        | 11951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 0.0633   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 1065     |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 191940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00016  |
# |    n_updates        | 11990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0528   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 1066     |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 192740   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000121 |
# |    n_updates        | 12040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 0.0617   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 1066     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 193256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 12072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0534   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 1066     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 194056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000144 |
# |    n_updates        | 12122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0534   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 1066     |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 194856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8e-05  |
# |    n_updates        | 12172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0534   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 1066     |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 195656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.64e-05 |
# |    n_updates        | 12222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 0.0619   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 1067     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 196456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.6e-05  |
# |    n_updates        | 12272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 0.0619   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 1067     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 197256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000105 |
# |    n_updates        | 12322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0525   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 1067     |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 198056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.29e-05 |
# |    n_updates        | 12372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 0.0525   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 1067     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 198856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000188 |
# |    n_updates        | 12422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 0.0615   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 1068     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 199304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.66e-05 |
# |    n_updates        | 12450    |
# ----------------------------------

# %%
model.save("dqn_action_empty")

# %%
model = DQN.load("dqn_action_empty",env=env_vec,tensorboard_log="./dqnactionrand/")

mean_reward, std_reward = evaluate_policy(model, env=env_vec, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 4.44GB
#   warnings.warn(
# Mean Reward: 0.0 +/- 0.0

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env_vec.step(action)
        #print(done)
        total_reward += reward
        env_vec.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.]

# %% [markdown]
# # Empty random room

# %%
register(
    id='custom_empty-v0',
    entry_point='emptyrandom:RandomGoalEmptyEnv',
    kwargs={}
)

# %%
#gym.pprint_registry()  # to see all registered environments

if 'custom_empty-v0' in gym.envs.registry:
    print("Environment 'custom_empty-v0' is registered.")
else:
    print("Environment 'custom_empty-v0' is NOT registered.")
# Out:
# Environment 'custom_empty-v0' is registered.

# %%
env_id2 = 'custom_empty-v0'
def create_env():
    env = gym.make(env_id2, render_mode="rgb_array",size=16)
    env = ActionWrapper(env)
    env = FlatObsWrapper(env)  
    return env

env_vec_ran = make_vec_env(create_env, n_envs=1)
env_vec_ran2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model2 = DQN("MlpPolicy", env_vec_ran2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnactionrandempty/"
            )

# Train the model
model2.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnactionrandempty/DQN_1
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 2.91GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | 0.097    |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1636     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000101 |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | 0.0485   |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1517     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | 0.0323   |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1462     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000109 |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | 0.0243   |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.66e-05 |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | 0.0194   |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1457     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.25e-05 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0492   |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1456     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.19e-05 |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | 0.0567   |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1449     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.29e-05 |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0496   |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1423     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58e-05 |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | 0.0441   |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1426     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.23e-05 |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | 0.0397   |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1416     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.4e-05  |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | 0.0431   |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1417     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.19e-05 |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | 0.0395   |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1404     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.64e-05 |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0481   |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1401     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5112     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.93e-05 |
# |    n_updates        | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | 0.0446   |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1384     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.29e-05 |
# |    n_updates        | 338      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | 0.0565   |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1385     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.73e-05 |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | 0.064    |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1372     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6256     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.46e-05 |
# |    n_updates        | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 0.0667   |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1369     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6516     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.79e-05 |
# |    n_updates        | 401      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | 0.063    |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1343     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6916     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.87e-05 |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | 0.0597   |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1348     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7316     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.49e-05 |
# |    n_updates        | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | 0.0567   |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1348     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7716     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.8e-05  |
# |    n_updates        | 476      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | 0.054    |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1348     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.63e-05 |
# |    n_updates        | 501      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | 0.057    |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1350     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8488     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.06e-05 |
# |    n_updates        | 524      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | 0.0614   |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1352     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.51e-05 |
# |    n_updates        | 547      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | 0.0599   |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1354     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9256     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.76e-05 |
# |    n_updates        | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | 0.0644   |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1357     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9616     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.6e-05  |
# |    n_updates        | 594      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | 0.0605   |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1354     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10016    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.66e-05 |
# |    n_updates        | 619      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | 0.0605   |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1351     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91e-05 |
# |    n_updates        | 644      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | 0.0605   |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1348     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 10816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.62e-05 |
# |    n_updates        | 669      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | 0.0605   |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1347     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.51e-05 |
# |    n_updates        | 694      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.0682   |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1348     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72e-05 |
# |    n_updates        | 718      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | 0.0602   |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1344     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.41e-05 |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | 0.0635   |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1343     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12176    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.74e-05 |
# |    n_updates        | 754      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | 0.0829   |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1341     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e-05 |
# |    n_updates        | 775      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | 0.0922   |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1343     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.79e-05 |
# |    n_updates        | 794      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | 0.103    |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1344     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13004    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4e-05  |
# |    n_updates        | 806      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 0.0995   |
# |    exploration_rate | 0.363    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1336     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000232 |
# |    n_updates        | 831      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 0.0995   |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1332     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13804    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.04e-05 |
# |    n_updates        | 856      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | 0.0975   |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1328     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16e-05 |
# |    n_updates        | 881      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | 0.0975   |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1326     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 14604    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.83e-05 |
# |    n_updates        | 906      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | 0.0971   |
# |    exploration_rate | 0.289    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1324     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 14960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.86e-05 |
# |    n_updates        | 928      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | 0.0984   |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1321     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15352    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000156 |
# |    n_updates        | 953      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      
    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 0.347    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2536     |
# |    fps              | 1149     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 198540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000201 |
# |    n_updates        | 12402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.7     |
# |    ep_rew_mean      | 0.346    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2540     |
# |    fps              | 1149     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 198720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 12413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.9     |
# |    ep_rew_mean      | 0.364    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2544     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199068   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 12435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.9     |
# |    ep_rew_mean      | 0.374    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2548     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00022  |
# |    n_updates        | 12439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.5     |
# |    ep_rew_mean      | 0.408    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2552     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00278  |
# |    n_updates        | 12449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.7     |
# |    ep_rew_mean      | 0.395    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2556     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000316 |
# |    n_updates        | 12463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 63.3     |
# |    ep_rew_mean      | 0.388    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2560     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000386 |
# |    n_updates        | 12479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 62.6     |
# |    ep_rew_mean      | 0.396    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2564     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000271 |
# |    n_updates        | 12487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.5     |
# |    ep_rew_mean      | 0.405    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2568     |
# |    fps              | 1149     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 199924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00241  |
# |    n_updates        | 12489    |
# ----------------------------------

# %%
model2.save("dqn_action_empty_ran")

# %%
model2 = DQN.load("dqn_action_empty_ran",env=env_vec_ran,tensorboard_log="./dqnactionrandempty/")

mean_reward, std_reward = evaluate_policy(model2, env=env_vec_ran, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 2.29GB
#   warnings.warn(
# Mean Reward: 0.07676 +/- 0.2603089364582015

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_ran.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model2.predict(obs)
        obs, reward, done, info = env_vec_ran.step(action)
        #print(done)
        total_reward += reward
        env_vec_ran.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_ran.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.928]
# Episode 2: Total Reward = [0.928]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.946]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.973]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.964]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.946]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.937]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.775]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.]
# Episode 26: Total Reward = [0.946]
# Episode 27: Total Reward = [0.208]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.154]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.19]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.91]
# Episode 35: Total Reward = [0.]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.586]
# Episode 38: Total Reward = [0.595]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.919]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.217]
# Episode 47: Total Reward = [0.964]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.26172]

# %% [markdown]
# # Now Four rooms

# %%
env_id3 = "MiniGrid-FourRooms-v0"
def create_env():
    env = gym.make(env_id3, render_mode="rgb_array")
    env = ActionWrapper(env)
    env = FlatObsWrapper(env)  
    return env

env_vec_four = make_vec_env(create_env, n_envs=1)
env_vec_four2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model3 = DQN("MlpPolicy", env_vec_four2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnactionfour/"
            )

# Train the model
model3.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# Logging to ./dqnactionfour/DQN_1
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 2.35GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1510     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000446 |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1363     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000185 |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1321     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.19e-05 |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1269     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000139 |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1277     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.97e-05 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | 0.0417   |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1248     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000134 |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | 0.0357   |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1240     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.58e-05 |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0659   |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1254     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.68e-05 |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | 0.0586   |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1242     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.54e-05 |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | 0.0527   |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1244     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17e-05 |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | 0.048    |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1236     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.61e-05 |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | 0.044    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1224     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.2e-05  |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | 0.0406   |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1219     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.97e-05 |
# |    n_updates        | 318      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | 0.0377   |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1220     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.92e-05 |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | 0.0352   |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1218     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.6e-05  |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | 0.033    |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1221     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.3e-05  |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.031    |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1216     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58e-05 |
# |    n_updates        | 418      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | 0.0293   |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1222     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | 0.0278   |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1223     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.18e-05 |
# |    n_updates        | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | 0.0356   |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1219     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7968     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.73e-05 |
# |    n_updates        | 491      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0339   |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1223     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.66e-05 |
# |    n_updates        | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | 0.0359   |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1228     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8768     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 541      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0343   |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1223     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9168     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6e-05    |
# |    n_updates        | 566      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | 0.0329   |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1227     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9568     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00154  |
# |    n_updates        | 591      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0316   |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1230     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9968     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.81e-05 |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0316   |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1231     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 10368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.62e-05 |
# |    n_updates        | 641      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.
    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98e-05 |
# |    n_updates        | 1741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | 0.0547   |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1182     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 28368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09e-05 |
# |    n_updates        | 1766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | 0.0517   |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1183     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 28768    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.78e-05 |
# |    n_updates        | 1791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.0471   |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1183     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 29168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43e-05 |
# |    n_updates        | 1816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.0471   |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1183     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 29568    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99e-05 |
# |    n_updates        | 1841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.0471   |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1183     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 29968    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-05 |
# |    n_updates        | 1866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | 0.0509   |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1183     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 30368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26e-05 |
# |    n_updates        | 1891     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | 0.0579   |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1183     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 30740    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000246 |
# |    n_updates        | 1915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.0485   |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1185     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 31140    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01e-05 |
# |    n_updates        | 1940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0445   |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1186     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 31540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72e-05 |
# |    n_updates        | 1965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0445   |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1186     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 31940    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76e-05 |
# |    n_updates        | 1990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0445   |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1185     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 32340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11e-05 |
# |    n_updates        | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0445   |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1187     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 32740    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62e-05 |
# |    n_updates        | 2040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | 0.0458   |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1187     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 33084    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34e-05 |
# |    n_updates        | 2061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | 0.037    |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1188     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 33484    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.31e-05 |
# |    n_updates        | 2086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | 0.0417   |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1188     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 33852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07e-05 |
# |    n_updates        | 2109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | 0.0363   |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1189     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 34252    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41e-05 |
# |    n_updates        | 2134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0435   |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1189     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 34368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.73e-06 |
# |    n_updates        | 2141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | 0.0495   |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1190     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 34752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49e-05 |
# ...
# |    time_elapsed     | 941      |
# |    total_timesteps  | 989484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.74e-05 |
# |    n_updates        | 61836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | 0.0999   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10856    |
# |    fps              | 1050     |
# |    time_elapsed     | 942      |
# |    total_timesteps  | 989884   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.6e-05  |
# |    n_updates        | 61861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | 0.0871   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10860    |
# |    fps              | 1050     |
# |    time_elapsed     | 942      |
# |    total_timesteps  | 990284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000294 |
# |    n_updates        | 61886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | 0.0818   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10864    |
# |    fps              | 1050     |
# |    time_elapsed     | 943      |
# |    total_timesteps  | 990684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.7e-05  |
# |    n_updates        | 61911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | 0.0818   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10868    |
# |    fps              | 1050     |
# |    time_elapsed     | 943      |
# |    total_timesteps  | 991084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.78e-05 |
# |    n_updates        | 61936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.066    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10872    |
# |    fps              | 1050     |
# |    time_elapsed     | 943      |
# |    total_timesteps  | 991484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36e-05 |
# |    n_updates        | 61961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.066    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10876    |
# |    fps              | 1050     |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 991884   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.66e-05 |
# |    n_updates        | 61986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | 0.0756   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10880    |
# |    fps              | 1050     |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 992084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000232 |
# |    n_updates        | 61999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | 0.0756   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10884    |
# |    fps              | 1050     |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 992484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17e-05 |
# |    n_updates        | 62024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.0673   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10888    |
# |    fps              | 1050     |
# |    time_elapsed     | 945      |
# |    total_timesteps  | 992884   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000302 |
# |    n_updates        | 62049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | 0.0578   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10892    |
# |    fps              | 1050     |
# |    time_elapsed     | 945      |
# |    total_timesteps  | 993284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.69e-05 |
# |    n_updates        | 62074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | 0.0578   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10896    |
# |    fps              | 1050     |
# |    time_elapsed     | 945      |
# |    total_timesteps  | 993684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000116 |
# |    n_updates        | 62099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | 0.0759   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10900    |
# |    fps              | 1050     |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 993976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.08e-05 |
# |    n_updates        | 62117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | 0.0765   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10904    |
# |    fps              | 1050     |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 994376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e-05 |
# |    n_updates        | 62142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | 0.0855   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10908    |
# |    fps              | 1050     |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 994620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00643  |
# |    n_updates        | 62157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | 0.0855   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10912    |
# |    fps              | 1050     |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 995020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.16e-05 |
# |    n_updates        | 62182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | 0.0824   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10916    |
# |    fps              | 1050     |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 995420   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96e-05 |
# |    n_updates        | 62207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | 0.0904   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10920    |
# |    fps              | 1050     |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 995700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.03e-05 |
# |    n_updates        | 62225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10924    |
# |    fps              | 1050     |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 995908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46e-05 |
# |    n_updates        | 62238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | 0.108    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10928    |
# |    fps              | 1050     |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 996296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.96e-05 |
# |    n_updates        | 62262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | 0.121    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10932    |
# |    fps              | 1050     |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 996576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000254 |
# |    n_updates        | 62279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | 0.115    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10936    |
# |    fps              | 1050     |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 996976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000117 |
# |    n_updates        | 62304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10940    |
# |    fps              | 1050     |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 997268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49e-05 |
# |    n_updates        | 62323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.7     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10944    |
# |    fps              | 1050     |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 997396   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000103 |
# |    n_updates        | 62331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | 0.151    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10948    |
# |    fps              | 1050     |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 997708   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98e-05 |
# |    n_updates        | 62350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | 0.151    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10952    |
# |    fps              | 1050     |
# |    time_elapsed     | 950      |
# |    total_timesteps  | 998108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.99e-05 |
# |    n_updates        | 62375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85       |
# |    ep_rew_mean      | 0.156    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10956    |
# |    fps              | 1050     |
# |    time_elapsed     | 950      |
# |    total_timesteps  | 998508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e-05 |
# |    n_updates        | 62400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 0.165    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10960    |
# |    fps              | 1050     |
# |    time_elapsed     | 950      |
# |    total_timesteps  | 998596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000192 |
# |    n_updates        | 62406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.7     |
# |    ep_rew_mean      | 0.159    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10964    |
# |    fps              | 1050     |
# |    time_elapsed     | 950      |
# |    total_timesteps  | 998996   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9e-05    |
# |    n_updates        | 62431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | 0.178    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10968    |
# |    fps              | 1050     |
# |    time_elapsed     | 951      |
# |    total_timesteps  | 999316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.86e-05 |
# |    n_updates        | 62451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.5     |
# |    ep_rew_mean      | 0.182    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10972    |
# |    fps              | 1050     |
# |    time_elapsed     | 951      |
# |    total_timesteps  | 999716   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12e-05 |
# |    n_updates        | 62476    |
# ----------------------------------

# %%
model3.save("dqn_action_four")

# %%
model3 = DQN.load("dqn_action_four",env=env_vec_four,tensorboard_log="./dqnactionfour/")

mean_reward, std_reward = evaluate_policy(model3, env=env_vec_four, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 0.24GB
#   warnings.warn(
# Mean Reward: 0.07676 +/- 0.2603711627657717

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_four.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model3.predict(obs)
        obs, reward, done, info = env_vec_four.step(action)
        #print(done)
        total_reward += reward
        env_vec_four.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_four.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.712]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.901]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.955]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.955]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.694]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.406]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.928]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.361]
# Episode 36: Total Reward = [0.145]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.991]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.]
# Episode 44: Total Reward = [0.685]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.15466]
