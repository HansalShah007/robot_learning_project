# %%
# # Step 1: Import necessary libraries
# import pandas as pd
# import seaborn as sns
# import os
# import matplotlib.pyplot as plt

# # Step 2: Load CSV files into pandas DataFrame
# folder_path = "ppo/episode_len_mean"
# files = os.listdir(folder_path)
# dfs = []

# for file in files:
#     if file.endswith(".csv"):
#         file_path = os.path.join(folder_path, file)
#         df = pd.read_csv(file_path)
#         # Assuming you want to ignore the 'wall_time' column
#         df.drop(columns=['Wall Time'], inplace=True, errors='ignore')
#         # Rename the 'value' column with the file name (without extension)
#         column_name = os.path.splitext(file)[0]
#         df.rename(columns={'Value': column_name}, inplace=True)
#         dfs.append(df)


# # # Merge all DataFrames into one on the 'step' column
# # combined_df = dfs[0]  # Start with the first DataFrame
# # for df in dfs[1:]:
# #     combined_df = pd.merge(combined_df, df, on='Step', how='outer')

# # Step 3: Plotting with seaborn
# # plt.figure(figsize=(10, 6))
# # for column in combined_df.columns[1:]:
# #     sns.scatterplot(data=combined_df, x='Step', y=column, label=column)

# plt.title('Scatter Plot of Step vs Value for Each CSV File')
# plt.xlabel('Step')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %% [markdown]
# **Load DQN Episode Length Mean**

# %%
import pandas as pd

ep_len_mean_dqn_vanilla_empty = pd.read_csv('dqn/ep_len_mean/dqn_vanilla_empty_DQN_1.csv')
ep_len_mean_dqn_vanilla_empty_random = pd.read_csv('dqn/ep_len_mean/dqn_vanilla_empty_random_DQN_1.csv')
ep_len_mean_dqn_vanilla_four = pd.read_csv('dqn/ep_len_mean/dqn_vanilla_four_DQN_1.csv')
ep_len_mean_dqn_action_empty = pd.read_csv('dqn/ep_len_mean/dqn_action_empty_DQN_1.csv')
ep_len_mean_dqn_action_empty_random = pd.read_csv('dqn/ep_len_mean/dqn_action_empty_random_DQN_1.csv')
ep_len_mean_dqn_action_four = pd.read_csv('dqn/ep_len_mean/dqn_action_four_DQN_1.csv')
ep_len_mean_dqn_reward_empty = pd.read_csv('dqn/ep_len_mean/dqn_reward_empty_DQN_2.csv')
ep_len_mean_dqn_reward_empty_random = pd.read_csv('dqn/ep_len_mean/dqn_reward_empty_random_DQN_1.csv')
ep_len_mean_dqn_reward_four = pd.read_csv('dqn/ep_len_mean/dqn_reward_four_DQN_2.csv')

# %% [markdown]
# **Load DQN Episode Reward Mean**

# %%
ep_rew_mean_dqn_vanilla_empty = pd.read_csv('dqn/ep_reward_mean/dqn_vanilla_empty_DQN_1.csv')
ep_rew_mean_dqn_vanilla_empty_random = pd.read_csv('dqn/ep_reward_mean/dqn_vanilla_empty_random_DQN_1.csv')
ep_rew_mean_dqn_vanilla_four = pd.read_csv('dqn/ep_reward_mean/dqn_vanilla_four_DQN_1.csv')
ep_rew_mean_dqn_action_empty = pd.read_csv('dqn/ep_reward_mean/dqn_action_empty_DQN_1.csv')
ep_rew_mean_dqn_action_empty_random = pd.read_csv('dqn/ep_reward_mean/dqn_action_empty_random_DQN_1.csv')
ep_rew_mean_dqn_action_four = pd.read_csv('dqn/ep_reward_mean/dqn_action_four_DQN_1.csv')
ep_rew_mean_dqn_reward_empty = pd.read_csv('dqn/ep_reward_mean/dqn_reward_empty_DQN_2.csv')
ep_rew_mean_dqn_reward_empty_random = pd.read_csv('dqn/ep_reward_mean/dqn_reward_empty_random_DQN_1.csv')
ep_rew_mean_dqn_reward_four = pd.read_csv('dqn/ep_reward_mean/dqn_reward_four_DQN_2.csv')

# %% [markdown]
# **Load PPO Episode Length Mean**

# %%
ep_len_mean_ppo_vanilla_empty = pd.read_csv('ppo/ep_len_mean/ppo_vanilla_empty_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_vanilla_empty_random = pd.read_csv('ppo/ep_len_mean/ppo_vanilla_empty_random_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_vanilla_four = pd.read_csv('ppo/ep_len_mean/ppo_vanilla_four_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_action_empty = pd.read_csv('ppo/ep_len_mean/ppo_action_empty_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_action_empty_random = pd.read_csv('ppo/ep_len_mean/ppo_action_empty_random_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_action_four = pd.read_csv('ppo/ep_len_mean/ppo_action_four_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_reward_empty = pd.read_csv('ppo/ep_len_mean/ppo_reward_empty_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_reward_empty_random = pd.read_csv('ppo/ep_len_mean/ppo_reward_empty_random_no_step_cap_PPO_1.csv')
ep_len_mean_ppo_reward_four = pd.read_csv('ppo/ep_len_mean/ppo_reward_four_no_step_cap_PPO_1.csv')

# %% [markdown]
# **Load PPO Episode Reward Mean**

# %%
ep_rew_mean_ppo_vanilla_empty = pd.read_csv('ppo/ep_rew_mean/ppo_vanilla_empty_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_vanilla_empty_random = pd.read_csv('ppo/ep_rew_mean/ppo_vanilla_empty_random_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_vanilla_four = pd.read_csv('ppo/ep_rew_mean/ppo_vanilla_four_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_action_empty = pd.read_csv('ppo/ep_rew_mean/ppo_action_empty_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_action_empty_random = pd.read_csv('ppo/ep_rew_mean/ppo_action_empty_random_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_action_four = pd.read_csv('ppo/ep_rew_mean/ppo_action_four_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_reward_empty = pd.read_csv('ppo/ep_rew_mean/ppo_reward_empty_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_reward_empty_random = pd.read_csv('ppo/ep_rew_mean/ppo_reward_empty_random_no_step_cap_PPO_1.csv')
ep_rew_mean_ppo_reward_four = pd.read_csv('ppo/ep_rew_mean/ppo_reward_four_no_step_cap_PPO_1.csv')

# %% [markdown]
# **Load A2C Episode Length Means**

# %%
ep_len_mean_a2c_vanilla_empty =         pd.read_csv('a2c/ep_len_mean/a2c_vanilla_empty_A2C_1.csv')
ep_len_mean_a2c_vanilla_empty_random =  pd.read_csv('a2c/ep_len_mean/a2c_vanilla_empty_random_A2C_1.csv')
ep_len_mean_a2c_vanilla_four =          pd.read_csv('a2c/ep_len_mean/a2c_vanilla_four_A2C_1.csv')
ep_len_mean_a2c_action_empty =          pd.read_csv('a2c/ep_len_mean/a2c_action_empty_A2C_1.csv')
ep_len_mean_a2c_action_empty_random =   pd.read_csv('a2c/ep_len_mean/a2c_action_empty_random_A2C_1.csv')
ep_len_mean_a2c_action_four =           pd.read_csv('a2c/ep_len_mean/a2c_action_four_A2C_1.csv')
ep_len_mean_a2c_reward_empty =          pd.read_csv('a2c/ep_len_mean/a2c_reward_empty_A2C_1.csv')
ep_len_mean_a2c_reward_empty_random =   pd.read_csv('a2c/ep_len_mean/a2c_reward_empty_random_A2C_1.csv')
ep_len_mean_a2c_reward_four =           pd.read_csv('a2c/ep_len_mean/a2c_reward_four_A2C_6.csv')

# %% [markdown]
# **Load A2C Episode Reward Means**

# %%
ep_rew_mean_a2c_vanilla_empty =         pd.read_csv('a2c/ep_rew_mean/a2c_vanilla_empty_A2C_1.csv')
ep_rew_mean_a2c_vanilla_empty_random =  pd.read_csv('a2c/ep_rew_mean/a2c_vanilla_empty_random_A2C_1.csv')
ep_rew_mean_a2c_vanilla_four =          pd.read_csv('a2c/ep_rew_mean/a2c_vanilla_four_A2C_1.csv')
ep_rew_mean_a2c_action_empty =          pd.read_csv('a2c/ep_rew_mean/a2c_action_empty_A2C_1.csv')
ep_rew_mean_a2c_action_empty_random =   pd.read_csv('a2c/ep_rew_mean/a2c_action_empty_random_A2C_1.csv')
ep_rew_mean_a2c_action_four =           pd.read_csv('a2c/ep_rew_mean/a2c_action_four_A2C_1.csv')
ep_rew_mean_a2c_reward_empty =          pd.read_csv('a2c/ep_rew_mean/a2c_reward_empty_A2C_1.csv')
ep_rew_mean_a2c_reward_empty_random =   pd.read_csv('a2c/ep_rew_mean/a2c_reward_empty_random_A2C_1.csv')
ep_rew_mean_a2c_reward_four =           pd.read_csv('a2c/ep_rew_mean/a2c_reward_four_A2C_6.csv')

# %%
ep_rew_mean_dqn_vanilla_empty
# Out:
#         Wall time    Step     Value
# 0    1.715394e+09     800  0.000000
# 1    1.715394e+09    1600  0.000000
# 2    1.715394e+09    2400  0.000000
# 3    1.715394e+09    3200  0.000000
# 4    1.715394e+09    4000  0.000000
# ..            ...     ...       ...
# 245  1.715394e+09  196800  0.008752
# 246  1.715394e+09  197600  0.008752
# 247  1.715394e+09  198400  0.008752
# 248  1.715394e+09  199200  0.008752
# 249  1.715394e+09  200000  0.008752
#
# [250 rows x 3 columns]

# %% [markdown]
# **Reward Mean Plot for Empty Room**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.lineplot(x=ep_rew_mean_dqn_vanilla_empty['Step']/1000, y=ep_rew_mean_dqn_vanilla_empty['Value'], linestyle="dashed", ax=axs[0])
sns.lineplot(x=ep_rew_mean_dqn_action_empty['Step']/1000, y=ep_rew_mean_dqn_action_empty['Value'], ax=axs[0])

sns.lineplot(x=ep_rew_mean_a2c_vanilla_empty['Step']/1000,  y=ep_rew_mean_a2c_vanilla_empty['Value'], linestyle="dashed",ax=axs[0])
sns.lineplot(x=ep_rew_mean_a2c_action_empty['Step']/1000, y=ep_rew_mean_a2c_action_empty['Value'], ax=axs[0])

sns.lineplot(x=ep_rew_mean_ppo_vanilla_empty['Step']/1000, y=ep_rew_mean_ppo_vanilla_empty['Value'], linestyle="dashed",ax=axs[0])
sns.lineplot(x=ep_rew_mean_ppo_action_empty['Step']/1000, y=ep_rew_mean_ppo_action_empty['Value'], ax=axs[0])

sns.lineplot(x=ep_len_mean_dqn_vanilla_empty['Step']/1000, y=ep_len_mean_dqn_vanilla_empty['Value'], label='DQN Vanilla', linestyle="dashed", ax=axs[1])
sns.lineplot(x=ep_len_mean_dqn_action_empty['Step']/1000, y=ep_len_mean_dqn_action_empty['Value'], label='DQN Action', ax=axs[1])

sns.lineplot(x=ep_len_mean_a2c_vanilla_empty['Step']/1000, y=ep_len_mean_a2c_vanilla_empty['Value'], label='A2C Vanilla', linestyle="dashed", ax=axs[1])
sns.lineplot(x=ep_len_mean_a2c_action_empty['Step']/1000, y=ep_len_mean_a2c_action_empty['Value'], label='A2C Action', ax=axs[1])

sns.lineplot(x=ep_len_mean_ppo_vanilla_empty['Step']/1000, y=ep_len_mean_ppo_vanilla_empty['Value'], label='PPO Vanilla', linestyle="dashed", ax=axs[1])
sns.lineplot(x=ep_len_mean_ppo_action_empty['Step']/1000, y=ep_len_mean_ppo_action_empty['Value'], label='PPO Action', ax=axs[1])


# Function to format x-axis ticks in terms of 1000s
def format_ticks(x, pos):
    return '{:.0f}K'.format(x / 1000)

axs[0].set_title('Episode Reward Means')
axs[0].set_xlabel('Timesteps (thousandth unit)')
axs[0].set_ylabel('Mean Reward')
axs[1].set_title('Episode Length Means')
axs[1].set_xlabel('Timesteps (thousandth unit)')
axs[1].set_ylabel('Mean Episode Length')


plt.suptitle('Model Performance in Empty Room Environment', fontsize=16)

# Show plot
plt.savefig('saved_plots/empty_room.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Reward Mean Plot for Empty Room with Random Reward Locations**

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.lineplot(x=ep_rew_mean_dqn_vanilla_empty_random['Step']/1000, 
             y=ep_rew_mean_dqn_vanilla_empty_random['Value'], 
             linestyle='dashed',
            ax=axs[0])
sns.lineplot(x=ep_rew_mean_dqn_action_empty_random['Step']/1000, 
             y=ep_rew_mean_dqn_action_empty_random['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_a2c_vanilla_empty_random['Step']/1000, 
             y=ep_rew_mean_a2c_vanilla_empty_random['Value'], 
             linestyle="dashed", 
             ax=axs[0])
sns.lineplot(x=ep_rew_mean_a2c_action_empty_random['Step']/1000, 
             y=ep_rew_mean_a2c_action_empty_random['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_ppo_vanilla_empty_random['Step']/1000, 
             y=ep_rew_mean_ppo_vanilla_empty_random['Value'], 
             linestyle="dashed",
             ax=axs[0])
sns.lineplot(x=ep_rew_mean_ppo_action_empty_random['Step']/1000, 
             y=ep_rew_mean_ppo_action_empty_random['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_len_mean_dqn_vanilla_empty_random['Step']/1000, 
             y=ep_len_mean_dqn_vanilla_empty_random['Value'], 
             label='DQN Vanilla',
             linestyle="dashed", 
             ax=axs[1])
sns.lineplot(x=ep_len_mean_dqn_action_empty_random['Step']/1000, 
             y=ep_len_mean_dqn_action_empty_random['Value'], 
             label='DQN Action', 
             ax=axs[1])

sns.lineplot(x=ep_len_mean_a2c_vanilla_empty_random['Step']/1000, 
             y=ep_len_mean_a2c_vanilla_empty_random['Value'], 
             label='A2c Vanilla',
             linestyle="dashed", 
             ax=axs[1])
sns.lineplot(x=ep_len_mean_a2c_action_empty_random['Step']/1000, 
             y=ep_len_mean_a2c_action_empty_random['Value'], 
             label='A2C Action', 
             ax=axs[1])

sns.lineplot(x=ep_len_mean_ppo_vanilla_empty_random['Step']/1000, 
             y=ep_len_mean_ppo_vanilla_empty_random['Value'], 
             label='PPO Vanilla',
             linestyle="dashed", 
             ax=axs[1])
sns.lineplot(x=ep_len_mean_ppo_action_empty_random['Step']/1000, 
             y=ep_len_mean_ppo_action_empty_random['Value'], 
             label='PPO Action', 
             ax=axs[1])

# Add labels and title
axs[0].set_title('Episode Reward Means')
axs[0].set_xlabel('Timesteps (thousandth unit)')
axs[0].set_ylabel('Mean Reward')
axs[1].set_title('Episode Length Means')
axs[1].set_xlabel('Timesteps (thousandth unit)')
axs[1].set_ylabel('Mean Episode Length')

plt.suptitle('Model Performance in Empty Room Enviornment\nwith Random Reward Locations', fontsize=16, y=1.02)

# Show plot
plt.savefig('saved_plots/empty_random_room.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Reward Mean Plot for Four Room**

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.lineplot(x=ep_rew_mean_dqn_vanilla_four['Step']/1000, 
             y=ep_rew_mean_dqn_vanilla_four['Value'], 
             linestyle="dashed",
             ax=axs[0])
sns.lineplot(x=ep_rew_mean_dqn_action_four['Step']/1000, 
             y=ep_rew_mean_dqn_action_four['Value'],
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_a2c_vanilla_four['Step']/1000, 
             y=ep_rew_mean_a2c_vanilla_four['Value'], 
             linestyle="dashed",
             ax=axs[0])
sns.lineplot(x=ep_rew_mean_a2c_action_four['Step']/1000, 
             y=ep_rew_mean_a2c_action_four['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_ppo_vanilla_four['Step']/1000, 
             y=ep_rew_mean_ppo_vanilla_four['Value'], 
             linestyle="dashed",
             ax=axs[0])
sns.lineplot(x=ep_rew_mean_ppo_action_four['Step']/1000, 
             y=ep_rew_mean_ppo_action_four['Value'], 
             ax=axs[0])


sns.lineplot(x=ep_len_mean_dqn_vanilla_four['Step']/1000, 
             y=ep_len_mean_dqn_vanilla_four['Value'], 
             label='DQN Vanilla',
             linestyle="dashed",
             ax=axs[1])
sns.lineplot(x=ep_len_mean_dqn_action_four['Step']/1000, 
             y=ep_len_mean_dqn_action_four['Value'], 
             label='DQN Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_a2c_vanilla_four['Step']/1000, 
             y=ep_len_mean_a2c_vanilla_four['Value'], 
             label='A2C Vanilla',
             linestyle='dashed',
             ax=axs[1])
sns.lineplot(x=ep_len_mean_a2c_action_four['Step']/1000, 
             y=ep_len_mean_a2c_action_four['Value'], 
             label='A2C Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_ppo_vanilla_four['Step']/1000, 
             y=ep_len_mean_ppo_vanilla_four['Value'], 
             label='PPO Vanilla',
             linestyle='dashed',
             ax=axs[1])
sns.lineplot(x=ep_len_mean_ppo_action_four['Step']/1000, 
             y=ep_len_mean_ppo_action_four['Value'], 
             label='PPO Action',
             ax=axs[1])


# Add labels and title
axs[0].set_title('Episode Reward Means')
axs[0].set_xlabel('Timesteps (thousandth unit)')
axs[0].set_ylabel('Mean Reward')
axs[1].set_title('Episode Length Means')
axs[1].set_xlabel('Timesteps (thousandth unit)')
axs[1].set_ylabel('Mean Episode Length')


plt.suptitle('Model Performance in Four Room Enviornment', fontsize=16)

# Show plot
plt.savefig('saved_plots/four_room.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Episode Length Mean for Empty Room**

# %%
import seaborn as sns
import matplotlib.ticker as ticker

sns.lineplot(x=ep_len_mean_dqn_vanilla_empty['Step']/1000, y=ep_len_mean_dqn_vanilla_empty['Value'], label='DQN Vanilla', linestyle="dashed")
sns.lineplot(x=ep_len_mean_dqn_action_empty['Step']/1000, y=ep_len_mean_dqn_action_empty['Value'], label='DQN Action')
#sns.scatterplot(x=ep_rew_mean_dqn_reward_empty['Step'], y=ep_rew_mean_dqn_reward_empty['Value'], label='DQN Reward Empty')

sns.lineplot(x=ep_len_mean_a2c_vanilla_empty['Step']/1000, y=ep_len_mean_a2c_vanilla_empty['Value'], label='A2C Vanilla', linestyle="dashed")
sns.lineplot(x=ep_len_mean_a2c_action_empty['Step']/1000, y=ep_len_mean_a2c_action_empty['Value'], label='A2C Action')

sns.lineplot(x=ep_len_mean_ppo_vanilla_empty['Step']/1000, y=ep_len_mean_ppo_vanilla_empty['Value'], label='PPO Vanilla', linestyle="dashed")
sns.lineplot(x=ep_len_mean_ppo_action_empty['Step']/1000, y=ep_len_mean_ppo_action_empty['Value'], label='PPO Action')
#sns.scatterplot(x=ep_rew_mean_ppo_reward_empty['Step'], y=ep_rew_mean_ppo_reward_empty['Value'], label='PPO Reward Empty')

# Function to format x-axis ticks in terms of 1000s
def format_ticks(x, pos):
    return '{:.0f}K'.format(x / 1000)

# Add labels and title
plt.xlabel('Timesteps (thousandth unit)')
plt.ylabel('Mean Episode Length')
plt.title('Episode Length Means in Empty Room')
#plt.xaxis.set_major_formatter(ticker.FuncFormatter(format_ticks))

# Add legend
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Show plot
plt.savefig('saved_plots/episode_length_empty_room.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Episode Length Mean for Empty Room with Random Reward Locations**

# %%
# sns.lineplot(x=ep_len_mean_dqn_vanilla_empty_random['Step']/1000, 
#              y=ep_len_mean_dqn_vanilla_empty_random['Value'], 
#              label='DQN Vanilla',
#              linestyle="dashed")
# sns.lineplot(x=ep_len_mean_dqn_action_empty_random['Step']/1000, 
#              y=ep_len_mean_dqn_action_empty_random['Value'], 
#              label='DQN Action')
# #sns.scatterplot(x=ep_rew_mean_dqn_reward_empty['Step'], y=ep_rew_mean_dqn_reward_empty['Value'], label='DQN Reward Empty')

# sns.lineplot(x=ep_len_mean_a2c_vanilla_empty_random['Step']/1000, 
#              y=ep_len_mean_a2c_vanilla_empty_random['Value'], 
#              label='A2c Vanilla',
#              linestyle="dashed")
# sns.lineplot(x=ep_len_mean_a2c_action_empty_random['Step']/1000, 
#              y=ep_len_mean_a2c_action_empty_random['Value'], 
#              label='A2C Action')

# sns.lineplot(x=ep_len_mean_ppo_vanilla_empty_random['Step']/1000, 
#              y=ep_len_mean_ppo_vanilla_empty_random['Value'], 
#              label='PPO Vanilla',
#              linestyle="dashed")
# sns.lineplot(x=ep_len_mean_ppo_action_empty_random['Step']/1000, 
#              y=ep_len_mean_ppo_action_empty_random['Value'], 
#              label='PPO Action')
# #sns.scatterplot(x=ep_rew_mean_ppo_reward_empty['Step'], y=ep_rew_mean_ppo_reward_empty['Value'], label='PPO Reward Empty')

# # Function to format x-axis ticks in terms of 1000s
# def format_ticks(x, pos):
#     return '{:.0f}K'.format(x / 1000)

# # Add labels and title
# plt.xlabel('Timesteps (thousandth unit)')
# plt.ylabel('Mean Episode Length')
# plt.title('Episode Length Means in Empty Room\nwith Random Reward Locations')
# #plt.xaxis.set_major_formatter(ticker.FuncFormatter(format_ticks))

# # Add legend
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# # Show plot
# plt.savefig('saved_plots/episode_length_empty_random_room.png', dpi=300, format='png', bbox_inches='tight')
# plt.show()

# %% [markdown]
# **Episode Length Mean for Four Room**

# %%
# sns.lineplot(x=ep_len_mean_dqn_vanilla_four['Step']/1000, 
#              y=ep_len_mean_dqn_vanilla_four['Value'], 
#              label='DQN Vanilla',
#              linestyle="dashed")
# sns.lineplot(x=ep_len_mean_dqn_action_four['Step']/1000, 
#              y=ep_len_mean_dqn_action_four['Value'], 
#              label='DQN Action')
# #sns.scatterplot(x=ep_rew_mean_dqn_reward_empty['Step'], y=ep_rew_mean_dqn_reward_empty['Value'], label='DQN Reward Empty')

# sns.lineplot(x=ep_len_mean_a2c_vanilla_four['Step']/1000, 
#              y=ep_len_mean_a2c_vanilla_four['Value'], 
#              label='A2C Vanilla',
#              linestyle='dashed')
# sns.lineplot(x=ep_len_mean_a2c_action_four['Step']/1000, 
#              y=ep_len_mean_a2c_action_four['Value'], 
#              label='A2C Action')

# sns.lineplot(x=ep_len_mean_ppo_vanilla_four['Step']/1000, 
#              y=ep_len_mean_ppo_vanilla_four['Value'], 
#              label='PPO Vanilla',
#              linestyle='dashed')
# sns.lineplot(x=ep_len_mean_ppo_action_four['Step']/1000, 
#              y=ep_len_mean_ppo_action_four['Value'], 
#              label='PPO Action')
# #sns.scatterplot(x=ep_rew_mean_ppo_reward_empty['Step'], y=ep_rew_mean_ppo_reward_empty['Value'], label='PPO Reward Empty')

# # Function to format x-axis ticks in terms of 1000s
# def format_ticks(x, pos):
#     return '{:.0f}K'.format(x / 1000)

# # Add labels and title
# plt.xlabel('Timesteps (thousandth unit)')
# plt.ylabel('Mean Episode Length')
# plt.title('Episode Length Means in Four Rooms')
# #plt.xaxis.set_major_formatter(ticker.FuncFormatter(format_ticks))

# # Add legend
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# # Show plot
# plt.savefig('saved_plots/episode_length_four_room.png', dpi=300, format='png', bbox_inches='tight')
# plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.lineplot(x=ep_rew_mean_dqn_reward_four['Step']/1000, 
             y=ep_rew_mean_dqn_reward_four['Value'],
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_a2c_reward_four['Step']/1000, 
             y=ep_rew_mean_a2c_reward_four['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_ppo_reward_four['Step']/1000, 
             y=ep_rew_mean_ppo_reward_four['Value'], 
             ax=axs[0])


sns.lineplot(x=ep_len_mean_dqn_reward_four['Step']/1000, 
             y=ep_len_mean_dqn_reward_four['Value'], 
             label='DQN Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_a2c_reward_four['Step']/1000, 
             y=ep_len_mean_a2c_reward_four['Value'], 
             label='A2C Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_ppo_reward_four['Step']/1000, 
             y=ep_len_mean_ppo_reward_four['Value'], 
             label='PPO Action',
             ax=axs[1])


# Add labels and title
axs[0].set_title('Episode Reward Means')
axs[0].set_xlabel('Timesteps (thousandth unit)')
axs[0].set_ylabel('Mean Reward')
axs[1].set_title('Episode Length Means')
axs[1].set_xlabel('Timesteps (thousandth unit)')
axs[1].set_ylabel('Mean Episode Length')


plt.suptitle('Reward Shaping Model Performance in Four Room Enviornment', fontsize=16)

# Show plot
plt.savefig('saved_plots/four_room_rewardshaping.png', dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 6))


sns.lineplot(x=ep_rew_mean_dqn_reward_empty['Step']/1000, 
             y=ep_rew_mean_dqn_reward_empty['Value'],
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_a2c_reward_empty['Step']/1000, 
             y=ep_rew_mean_a2c_reward_empty['Value'], 
             ax=axs[0])

sns.lineplot(x=ep_rew_mean_ppo_reward_empty['Step']/1000, 
             y=ep_rew_mean_ppo_reward_empty['Value'], 
             ax=axs[0])


sns.lineplot(x=ep_len_mean_dqn_reward_empty['Step']/1000, 
             y=ep_len_mean_dqn_reward_empty['Value'], 
             label='DQN Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_a2c_reward_empty['Step']/1000, 
             y=ep_len_mean_a2c_reward_empty['Value'], 
             label='A2C Action',
             ax=axs[1])

sns.lineplot(x=ep_len_mean_ppo_reward_empty['Step']/1000, 
             y=ep_len_mean_ppo_reward_empty['Value'], 
             label='PPO Action',
             ax=axs[1])


# Add labels and title
axs[0].set_title('Episode Reward Means')
axs[0].set_xlabel('Timesteps (thousandth unit)')
axs[0].set_ylabel('Mean Reward')
axs[1].set_title('Episode Length Means')
axs[1].set_xlabel('Timesteps (thousandth unit)')
axs[1].set_ylabel('Mean Episode Length')


plt.suptitle('Reward Shaping Model Performance in Empty Room Enviornment', fontsize=16)

# Show plot
plt.savefig('saved_plots/empty_room_rewardshaping.png', dpi=300, format='png', bbox_inches='tight')
plt.show()
