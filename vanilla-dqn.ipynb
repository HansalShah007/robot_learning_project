# %% [markdown]
# # Vanilla DQN
#
# Run on 3 environments
#
# Empty Room
#
# Empty Room Random
#
# Four Rooms

# %%
import gymnasium as gym
import minigrid
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from minigrid.wrappers import FlatObsWrapper
import time
import numpy as np
from minigrid.core.world_object import Goal
import random
from stable_baselines3.common.callbacks import BaseCallback
from gymnasium.envs.registration import register
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# c:\Users\josep\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # First Empty

# %%
# Create and wrap the environment
env_id = "MiniGrid-Empty-16x16-v0"

# %%
def create_env():
    env = gym.make(env_id, render_mode="rgb_array",max_episode_steps=200)
    env = FlatObsWrapper(env)  
    return env

# Use the function in make_vec_env
env_vec = make_vec_env(create_env, n_envs=1)
env_vec2 = make_vec_env(create_env, n_envs=4)

# %%
model = DQN("MlpPolicy", env_vec2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnvanillarand/"
            )

# Train the model
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnvanillarand/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1535     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00141  |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1470     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000377 |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1448     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.42e-05 |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1427     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.71e-05 |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1416     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.94e-05 |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1393     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-05 |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1352     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.32e-05 |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1361     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.51e-05 |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1365     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.15e-05 |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1360     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.57e-05 |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1362     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.73e-05 |
# |    n_updates        | 543      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1367     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.63e-05 |
# |    n_updates        | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1362     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.39e-05 |
# |    n_updates        | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1362     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81e-05 |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1355     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22e-05 |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1351     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02e-05 |
# |    n_updates        | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1346     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.99e-05 |
# |    n_updates        | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1337     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.35e-05 |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1332     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.21e-05 |
# |    n_updates        | 943      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1328     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61e-05 |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1328     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-05 |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1328     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47e-05 |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1326     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17e-05 |
# |    n_updates        | 1143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1326     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.15e-05 |
# |    n_updates        | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1320     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.76e-06 |
# |    n_updates        | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1321     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19e-05 |
# |    n_updates        | 1293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1320     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-05 |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1322     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 22400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.52e-06 |
# |    n_updates        | 1393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1324     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.49e-06 |
# |    n_updates        | 1443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1324     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.99e-06 |
# |    n_updates        | 1493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1324     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.83e-06 |
# |    n_updates        | 1543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1325     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 25600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.41e-06 |
# |    n_updates        | 1593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1327     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15e-05 |
# |    n_updates        | 1643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1327     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.06e-06 |
# |    n_updates        | 1693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1325     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.64e-06 |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1322     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.94e-06 |
# |    n_updates        | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1322     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 29600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-05 |
# |    n_updates        | 1843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1322     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02e-06 |
# |    n_updates        | 1893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1319     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 31200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5e-06    |
# |    n_updates        | 1943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1317     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68e-06 |
# |    n_updates        | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1317     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 32800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7e-06  |
# |    n_updates        | 2043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1315     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 33600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.29e-06 |
# |    n_updates        | 2093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1314     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 34400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94e-06 |
# |    n_updates        | 2143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1312     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 35200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04e-06 |
# |    n_updates        | 2193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1311     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72e-06 |
# |    n_updates        | 2243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1310     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 36800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.23e-06 |
# |    n_updates        | 2293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1308     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 37600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54e-06 |
# |    n_updates        | 2343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1307     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 38400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11e-06 |
# |    n_updates        | 2393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1307     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 39200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08e-06 |
# |    n_updates        | 2443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1308     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.9e-06  |
# |    n_updates        | 2493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 
    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 1260     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 184000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.9e-05  |
# |    n_updates        | 11493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 1260     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 184800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.74e-06 |
# |    n_updates        | 11543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 1260     |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 185600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.86e-06 |
# |    n_updates        | 11593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 1260     |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 186400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38e-06 |
# |    n_updates        | 11643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 1260     |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 187200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.93e-06 |
# |    n_updates        | 11693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 1260     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 188000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4e-06  |
# |    n_updates        | 11743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 1260     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 188800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.79e-07 |
# |    n_updates        | 11793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 1260     |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 189600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.92e-07 |
# |    n_updates        | 11843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 1260     |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 190400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62e-06 |
# |    n_updates        | 11893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 1260     |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 191200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07e-06 |
# |    n_updates        | 11943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 1259     |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 192000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59e-06 |
# |    n_updates        | 11993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 1259     |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 192800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-06 |
# |    n_updates        | 12043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 1259     |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 193600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.61e-07 |
# |    n_updates        | 12093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 1259     |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 194400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2e-06  |
# |    n_updates        | 12143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 1259     |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 195200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63e-06 |
# |    n_updates        | 12193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 1258     |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 196000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26e-06 |
# |    n_updates        | 12243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 1258     |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 196800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.07e-06 |
# |    n_updates        | 12293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 1258     |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 197600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.38e-06 |
# |    n_updates        | 12343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 1258     |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 198400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51e-06 |
# |    n_updates        | 12393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 1258     |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 199200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.6e-07  |
# |    n_updates        | 12443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 0.00875  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 1257     |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 200000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47e-06 |
# |    n_updates        | 12493    |
# ----------------------------------

# %%
model.save("dqn_action_empty")

# %%
model = DQN.load("dqn_action_empty",env=env_vec,tensorboard_log="./dqnvanillarand/")

mean_reward, std_reward = evaluate_policy(model, env=env_vec, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 5.50GB
#   warnings.warn(
# Mean Reward: 0.0 +/- 0.0

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env_vec.step(action)
        #print(done)
        total_reward += reward
        env_vec.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.]

# %% [markdown]
# # Empty random room

# %%
register(
    id='custom_empty-v0',
    entry_point='emptyrandom:RandomGoalEmptyEnv',
    kwargs={}
)

# %%
#gym.pprint_registry()  # to see all registered environments

if 'custom_empty-v0' in gym.envs.registry:
    print("Environment 'custom_empty-v0' is registered.")
else:
    print("Environment 'custom_empty-v0' is NOT registered.")
# Out:
# Environment 'custom_empty-v0' is registered.

# %%
env_id2 = 'custom_empty-v0'
def create_env():
    env = gym.make(env_id2, render_mode="rgb_array",size=16)
    env = FlatObsWrapper(env)  
    return env

env_vec_ran = make_vec_env(create_env, n_envs=1)
env_vec_ran2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model2 = DQN("MlpPolicy", env_vec_ran2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnvanillarandempty/"
            )

# Train the model
model2.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Logging to ./dqnvanillarandempty/DQN_1
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 5.52GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1847     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0032   |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1783     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00144  |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1758     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000672 |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1736     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000126 |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1706     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000228 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1706     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000133 |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1697     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000147 |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1694     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.55e-05 |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1677     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.91e-05 |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | 0.0212   |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1672     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.88e-05 |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | 0.0192   |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1675     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.98e-05 |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | 0.0176   |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1675     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.94e-05 |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | 0.0163   |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1657     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.5e-05  |
# |    n_updates        | 318      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 0.0151   |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1656     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.19e-05 |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | 0.0141   |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1657     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.42e-05 |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | 0.0132   |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1659     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.51e-05 |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0315   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 1365     |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 192480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00014  |
# |    n_updates        | 12023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0315   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 1365     |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 192880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000129 |
# |    n_updates        | 12048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0315   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 1364     |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 193280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000225 |
# |    n_updates        | 12073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | 0.0414   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 1364     |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 193464   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.74e-05 |
# |    n_updates        | 12085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | 0.0468   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 1363     |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 193804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00183  |
# |    n_updates        | 12106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | 0.056    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 1363     |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 194120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000131 |
# |    n_updates        | 12126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.0629   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 1362     |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 194520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000495 |
# |    n_updates        | 12151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.0629   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 1362     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 194920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000101 |
# |    n_updates        | 12176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 0.0629   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 1362     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 195320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.59e-05 |
# |    n_updates        | 12201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 0.0615   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 1362     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 195680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00017  |
# |    n_updates        | 12223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 0.0615   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 1361     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 196080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000266 |
# |    n_updates        | 12248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 0.0615   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 1361     |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 196480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.06e-05 |
# |    n_updates        | 12273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 0.0615   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 1361     |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 196880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.94e-05 |
# |    n_updates        | 12298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 1361     |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 197280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00013  |
# |    n_updates        | 12323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 1361     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 197680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.26e-05 |
# |    n_updates        | 12348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 1360     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58e-05 |
# |    n_updates        | 12373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 1360     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000161 |
# |    n_updates        | 12398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 1360     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 198880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.82e-05 |
# |    n_updates        | 12423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 1359     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000324 |
# |    n_updates        | 12448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | 0.0632   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 1359     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.57e-05 |
# |    n_updates        | 12473    |
# ----------------------------------

# %%
model2.save("dqn_action_empty_ran")

# %%
model2 = DQN.load("dqn_action_empty_ran",env=env_vec_ran,tensorboard_log="./dqnvanillarandempty/")

mean_reward, std_reward = evaluate_policy(model2, env=env_vec_ran, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 5.55GB
#   warnings.warn(
# Mean Reward: 0.0 +/- 0.0

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_ran.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model2.predict(obs)
        obs, reward, done, info = env_vec_ran.step(action)
        #print(done)
        total_reward += reward
        env_vec_ran.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_ran.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.424]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.00848]

# %% [markdown]
# # Now Four rooms

# %%
env_id3 = "MiniGrid-FourRooms-v0"
def create_env():
    env = gym.make(env_id3, render_mode="rgb_array")
    env = FlatObsWrapper(env)  
    return env

env_vec_four = make_vec_env(create_env, n_envs=1)
env_vec_four2 = make_vec_env(create_env, n_envs=4)

# %%
# Initialize the DQN model
model3 = DQN("MlpPolicy", env_vec_four2, verbose=1,
            learning_rate = 0.0001,
            buffer_size = 1000000,
            learning_starts = 100,
            batch_size = 32,
            tau = 1,
            gamma = 0.99,
            exploration_fraction = 0.1,
            exploration_initial_eps = 1,
            exploration_final_eps = 0.05,
            tensorboard_log="./dqnvanillafour/"
            )

# Train the model
model3.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# Logging to ./dqnvanillafour/DQN_1
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 5.32GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | 0.104    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1635     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | 0.0519   |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1547     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00689  |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | 0.0346   |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1506     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00407  |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | 0.0259   |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1487     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | 0.0207   |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1466     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000397 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 0.0173   |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1455     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000332 |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0325   |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1446     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00018  |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | 0.053    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1428     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00036  |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | 0.0473   |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1422     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000404 |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | 0.0427   |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1423     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00046  |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | 0.0389   |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 
|
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.49e-05 |
# |    n_updates        | 1631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 0.0178   |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1345     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.89e-05 |
# |    n_updates        | 1656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 0.0178   |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1345     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27008    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.83e-05 |
# |    n_updates        | 1681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | 0.0149   |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1344     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27408    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.2e-05  |
# |    n_updates        | 1706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | 0.0149   |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1343     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27808    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.63e-05 |
# |    n_updates        | 1731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 0.0171   |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1343     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.18e-05 |
# |    n_updates        | 1756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1343     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.76e-05 |
# |    n_updates        | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1340     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.43e-05 |
# |    n_updates        | 1803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1340     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.51e-05 |
# |    n_updates        | 1828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1337     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 29760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.74e-05 |
# |    n_updates        | 1853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1338     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000153 |
# |    n_updates        | 1878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 0.028    |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1338     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.63e-05 |
# |    n_updates        | 1903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0321   |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1338     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 30868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.4e-05  |
# |    n_updates        | 1923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0321   |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1337     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 31268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08e-05 |
# |    n_updates        | 1948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 0.0334   |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1336     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 31668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09e-05 |
# |    n_updates        | 1973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1336     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 32068    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07e-05 |
# |    n_updates        | 1998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1335     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 32468    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46e-05 |
# |    n_updates        | 2023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1335     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 32868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.84e-05 |
# |    n_updates        | 2048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1335     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 33268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81e-05 |
# |    n_updates        | 2073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1335     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 33668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99e-05 |
# |    n_updates        | 2098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 0.0373   |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1335     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 34068    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17e-05 |
# |    n_updates        | 2123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | 0.037    |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1335     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 34300    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.5e-05  |
# |    n_updates        | 2137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | 0.0399   |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1335     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 34616    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e-05 |
# |    n_updates        | 2157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0457   |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1335     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 34976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.49e-05 |
# |    n_updates        | 2179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | 0.0457   |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1335     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 35376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.84e-05 |
# |    n_updates        | 2204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | 0.0516   |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1334     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 35776    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.48e-05 |
# ...
# |    time_elapsed     | 872      |
# |    total_timesteps  | 987912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.32e-06 |
# |    n_updates        | 61738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10108    |
# |    fps              | 1131     |
# |    time_elapsed     | 873      |
# |    total_timesteps  | 988312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43e-05 |
# |    n_updates        | 61763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10112    |
# |    fps              | 1131     |
# |    time_elapsed     | 873      |
# |    total_timesteps  | 988712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.48e-05 |
# |    n_updates        | 61788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10116    |
# |    fps              | 1131     |
# |    time_elapsed     | 873      |
# |    total_timesteps  | 989112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41e-05 |
# |    n_updates        | 61813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10120    |
# |    fps              | 1131     |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 989436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.94e-06 |
# |    n_updates        | 61833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10124    |
# |    fps              | 1131     |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 989836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.43e-05 |
# |    n_updates        | 61858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10128    |
# |    fps              | 1131     |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 990236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000107 |
# |    n_updates        | 61883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10132    |
# |    fps              | 1131     |
# |    time_elapsed     | 875      |
# |    total_timesteps  | 990636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.97e-05 |
# |    n_updates        | 61908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10136    |
# |    fps              | 1131     |
# |    time_elapsed     | 875      |
# |    total_timesteps  | 991036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.86e-05 |
# |    n_updates        | 61933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10140    |
# |    fps              | 1131     |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 991436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 61958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10144    |
# |    fps              | 1131     |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 991836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08e-05 |
# |    n_updates        | 61983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10148    |
# |    fps              | 1131     |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 992236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.05e-05 |
# |    n_updates        | 62008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10152    |
# |    fps              | 1131     |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 992636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000115 |
# |    n_updates        | 62033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 0.00631  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10156    |
# |    fps              | 1131     |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 993036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-05 |
# |    n_updates        | 62058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10160    |
# |    fps              | 1131     |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 993436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000103 |
# |    n_updates        | 62083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10164    |
# |    fps              | 1131     |
# |    time_elapsed     | 878      |
# |    total_timesteps  | 993836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000142 |
# |    n_updates        | 62108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10168    |
# |    fps              | 1131     |
# |    time_elapsed     | 878      |
# |    total_timesteps  | 994236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7e-05  |
# |    n_updates        | 62133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10172    |
# |    fps              | 1131     |
# |    time_elapsed     | 879      |
# |    total_timesteps  | 994636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8e-05  |
# |    n_updates        | 62158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10176    |
# |    fps              | 1131     |
# |    time_elapsed     | 879      |
# |    total_timesteps  | 995036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 62183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10180    |
# |    fps              | 1131     |
# |    time_elapsed     | 879      |
# |    total_timesteps  | 995436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44e-05 |
# |    n_updates        | 62208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10184    |
# |    fps              | 1131     |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 995836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73e-05 |
# |    n_updates        | 62233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10188    |
# |    fps              | 1131     |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 996236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.79e-05 |
# |    n_updates        | 62258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10192    |
# |    fps              | 1131     |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 996636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18e-05 |
# |    n_updates        | 62283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10196    |
# |    fps              | 1131     |
# |    time_elapsed     | 881      |
# |    total_timesteps  | 997036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.59e-05 |
# |    n_updates        | 62308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10200    |
# |    fps              | 1131     |
# |    time_elapsed     | 881      |
# |    total_timesteps  | 997436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61e-05 |
# |    n_updates        | 62333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10204    |
# |    fps              | 1131     |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 997836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.35e-05 |
# |    n_updates        | 62358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10208    |
# |    fps              | 1131     |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 998236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21e-05 |
# |    n_updates        | 62383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10212    |
# |    fps              | 1131     |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 998636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77e-05 |
# |    n_updates        | 62408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | 0.00992  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10216    |
# |    fps              | 1131     |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 999036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-05 |
# |    n_updates        | 62433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | 0.00361  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10220    |
# |    fps              | 1131     |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 999436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62e-05 |
# |    n_updates        | 62458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | 0.00361  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10224    |
# |    fps              | 1131     |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 999836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72e-05 |
# |    n_updates        | 62483    |
# ----------------------------------

# %%
model3.save("dqn_action_four")

# %%
model3 = DQN.load("dqn_action_four",env=env_vec_four,tensorboard_log="./dqnvanillafour/")

mean_reward, std_reward = evaluate_policy(model3, env=env_vec_four, n_eval_episodes=50)
print(f"Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# c:\Users\josep\anaconda3\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.69GB > 0.25GB
#   warnings.warn(
# Mean Reward: 0.0 +/- 0.0

# %%
num_episodes = 50
total_rewards = []  # List to store total rewards for each episode

for episode in range(num_episodes):
    obs = env_vec_four.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model3.predict(obs)
        obs, reward, done, info = env_vec_four.step(action)
        #print(done)
        total_reward += reward
        env_vec_four.render('human')  # Render the environment at each step
        #time.sleep(0.05)  # Adjust this to control the speed of the rendering
    total_rewards.append(total_reward)  # Store the total reward for this episode
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate the average reward across all episodes
average_reward = sum(total_rewards) / num_episodes
print(f"Average Reward over {num_episodes} episodes: {average_reward}")

env_vec_four.close()  # Close the environment when done
# Out:
# Episode 1: Total Reward = [0.]
# Episode 2: Total Reward = [0.]
# Episode 3: Total Reward = [0.]
# Episode 4: Total Reward = [0.]
# Episode 5: Total Reward = [0.]
# Episode 6: Total Reward = [0.]
# Episode 7: Total Reward = [0.]
# Episode 8: Total Reward = [0.]
# Episode 9: Total Reward = [0.]
# Episode 10: Total Reward = [0.]
# Episode 11: Total Reward = [0.]
# Episode 12: Total Reward = [0.]
# Episode 13: Total Reward = [0.]
# Episode 14: Total Reward = [0.]
# Episode 15: Total Reward = [0.]
# Episode 16: Total Reward = [0.]
# Episode 17: Total Reward = [0.]
# Episode 18: Total Reward = [0.]
# Episode 19: Total Reward = [0.]
# Episode 20: Total Reward = [0.]
# Episode 21: Total Reward = [0.]
# Episode 22: Total Reward = [0.]
# Episode 23: Total Reward = [0.]
# Episode 24: Total Reward = [0.]
# Episode 25: Total Reward = [0.]
# Episode 26: Total Reward = [0.]
# Episode 27: Total Reward = [0.]
# Episode 28: Total Reward = [0.]
# Episode 29: Total Reward = [0.]
# Episode 30: Total Reward = [0.]
# Episode 31: Total Reward = [0.]
# Episode 32: Total Reward = [0.]
# Episode 33: Total Reward = [0.]
# Episode 34: Total Reward = [0.]
# Episode 35: Total Reward = [0.]
# Episode 36: Total Reward = [0.]
# Episode 37: Total Reward = [0.]
# Episode 38: Total Reward = [0.]
# Episode 39: Total Reward = [0.]
# Episode 40: Total Reward = [0.]
# Episode 41: Total Reward = [0.]
# Episode 42: Total Reward = [0.]
# Episode 43: Total Reward = [0.]
# Episode 44: Total Reward = [0.]
# Episode 45: Total Reward = [0.]
# Episode 46: Total Reward = [0.]
# Episode 47: Total Reward = [0.]
# Episode 48: Total Reward = [0.]
# Episode 49: Total Reward = [0.]
# Episode 50: Total Reward = [0.]
# Average Reward over 50 episodes: [0.]
